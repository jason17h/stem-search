# %%
import json
import pickle

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %% [markdown]
# Note that the data contains information on STEM and economic research papers and journals, sourced from arXiv.org.

# %%
data = []
for line in open('data/arxiv-metadata-oai-2020-03-23.json'):
    data.append(json.loads(line))

# %%
df_raw = pd.DataFrame(data)

# %%
df_raw.head(3)
# Out:
#           id       submitter  \
# 0  0704.0001  Pavel Nadolsky
# 1  0704.0002    Louis Theran
# 2  0704.0003     Hongjun Pan
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
#
#                                   comments               journal-ref  \
# 0  37 pages, 15 figures; published version  Phys.Rev.D76:013009,2007
# 1    To appear in Graphs and Combinatorics                      None
# 2                      23 pages, 3 figures                      None
#
#                           doi  \
# 0  10.1103/PhysRevD.76.013009
# 1                        None
# 2                        None
#
#                                             abstract         report-no  \
# 0    A fully differential calculation in perturba...  ANL-HEP-PR-07-12
# 1    We describe a new algorithm, the $(k,\ell)$-...              None
# 2    The evolution of Earth-Moon system is descri...              None
#
#          categories      versions
# 0          [hep-ph]      [v1, v2]
# 1   [math.CO cs.CG]      [v1, v2]
# 2  [physics.gen-ph]  [v1, v2, v3]

# %%
with open('data/authors-parsed.json') as f:
    authors_parsed = json.load(f)

# %%
authors_parsed
# Out:
# {'0704.0001': [['Balázs', 'C.', ''],
#   ['Berger', 'E. L.', ''],
#   ['Nadolsky', 'P. M.', ''],
#   ['Yuan', 'C. -P.', '']],
#  '0704.0002': [['Streinu', 'Ileana', ''], ['Theran', 'Louis', '']],
#  '0704.0003': [['Pan', 'Hongjun', '']],
#  '0704.0004': [['Callan', 'David', '']],
#  '0704.0005': [['Abu-Shammala', 'Wael', ''], ['Torchinsky', 'Alberto', '']],
#  '0704.0006': [['Pong', 'Y. H.', ''], ['Law', 'C. K.', '']],
#  '0704.0007': [['Corichi', 'Alejandro', ''],
#   ['Vukasinac', 'Tatjana', ''],
#   ['Zapata', 'Jose A.', '']],
#  '0704.0008': [['Swift', 'Damian C.', '']],
#  '0704.0009': [['Harvey', 'Paul', ''],
#   ['Merin', 'Bruno', ''],
#   ['Huard', 'Tracy L.', ''],
#   ['Rebull', 'Luisa M.', ''],
#   ['Chapman', 'Nicholas', ''],
#   ['Evans', 'Neal J.', 'II'],
#   ['Myers', 'Philip C.', '']],
#  '0704.0010': [['Ovchinnikov', 'Sergei', '']],
#  '0704.0011': [['Cunningham', 'Clifton', ''], ['Dembele', 'Lassina', '']],
#  '0704.0012': [['Choi', 'Dohoon', '']],
#  '0704.0013': [['Choi', 'Dohoon', ''], ['Choie', 'YoungJu', '']],
#  '0704.0014': [['Fujii', 'Koichi', '']],
#  '0704.0015': [['Stahn', 'Christian', '']],
#  '0704.0016': [['Chang', 'Chao-Hsi', ''],
#   ['Li', 'Tong', ''],
#   ['Li', 'Xue-Qian', ''],
#   ['Wang', 'Yu-Ming', '']],
#  '0704.0017': [['Mhlahlo', 'Nceba', ''],
#   ['Buckley', 'David H.', ''],
#   ['Dhillon', 'Vikram S.', ''],
#   ['Potter', 'Steven B.', ''],
#   ['Warner', 'Brian', ''],
#   ['Woudt', 'Patric A.', '']],
#  '0704.0018': [['Gustavsson', 'Andreas', '']],
#  '0704.0019': [['Konno', 'Norio', '']],
#  '0704.0020': [['The BABAR Collaboration', '', ''], ['Aubert', 'B.', '']],
#  '0704.0021': [['Casagrande', 'Vanessa', ''],
#   ['Togashi', 'Yuichi', ''],
#   ['Mikhailov', 'Alexander S.', '']],
#  '0704.0022': [['Malham', 'Simon J. A.', ''], ['Wiese', 'Anke', '']],
#  '0704.0023': [['Loukitcheva', 'M. A.', ''],
#   ['Solanki', 'S. K.', ''],
#   ['White', 'S.', '']],
#  '0704.0024': [['Serga', 'A. A.', ''],
#   ['Kostylev', 'M.', ''],
#   ['Hillebrands', 'B.', '']],
#  '0704.0025': [['Mishchenko', 'A. S.', '', '1 and 2'],
#   ['Nagaosa', 'N.', '', '1 and 3']],
#  '0704.0026': [['de Marrais', 'Robert P. C.', '']],
#  '0704.0027': [['Goerbig', 'M. O.', ''],
#   ['Fuchs', 'J. -N.', ''],
#   ['Kechedzhi', 'K.', ''],
#   ["Fal'ko", 'Vladimir I.', '']],
#  '0704.0028': [['Frenkel', 'Péter E.', '']],
#  '0704.0029': [['Shu', 'Zhan', ''],
#   ['Chen', 'Xiao-Lin', ''],
#   ['Deng', 'Wei-Zhen', '']],
#  '0704.0030': [['Hague', 'J. P.', ''], ["d'Ambrumenil", 'N.', '']],
#  '0704.0031': [['Biryukov', 'V. M.', '', 'Serpukhov, IHEP']],
#  '0704.0032': [['Esteban-Pretel', 'A.', ''],
#   ['Tomàs', 'R.', ''],
#   ['Valle', 'J. W. F.', '']],
#  '0704.0033': [['Yurkin', 'Maxim A.', ''],
#   ['Maltsev', 'Valeri P.', ''],
#   ['Hoekstra', 'Alfons G.', '']],
#  '0704.0034': [['Ogryzko', 'Vasily', '']],
#  '0704.0035': [['Yurkin', 'Maxim A.', ''],
#   ['Maltsev', 'Valeri P.', ''],
#   ['Hoekstra', 'Alfons G.', '']],
#  '0704.0036': [['Wang', 'Liming', ''], ['Sontag', 'Eduardo D.', '']],
#  '0704.0037': [['Yurkin', 'Maxim A.', ''],
#   ['Maltsev', 'Valeri P.', ''],
#   ['Hoekstra', 'Alfons G.', '']],
#  '0704.0038': [['Yurkin', 'Maxim A.', ''], ['Hoekstra', 'Alfons G.', '']],
#  '0704.0039': [['Oller', 'Jose A.', ''], ['Roca', 'Luis', '']],
#  '0704.0040': [['Popa', 'Mihai', '']],
#  '0704.0041': [['Goswami', 'Debashish', '']],
#  '0704.0042': [['Licata', 'Ignazio', '']],
#  '0704.0043': [['Brownlee', 'R. A.', ''],
#   ['Gorban', 'A. N.', ''],
#   ['Levesley', 'J.', '']],
#  '0704.0044': [['Schekochihin', 'A. A.', '', 'Oxford'],
#   ['Cowley', 'S. C.', '', 'Culham'],
#   ['Dorland', 'W.', '', 'Maryland'],
#   ['Hammett', 'G. W.', '', 'Princeton'],
#   ['Howes', 'G. G.', '', 'Iowa'],
#   ['Quataert', 'E.', '', 'Berkeley'],
#   ['Tatsuno', 'T.', '', 'Maryland']],
#  '0704.0045': [['El', 'G. A.', ''],
#   ['Grimshaw', 'R. H. J.', ''],
#   ['Kamchatnov', 'A. M.', '']],
#  '0704.0046': [['Csiszar', 'I.', ''], ['Hiai', 'F.', ''], ['Petz', 'D.', '']],
#  '0704.0047': [['Kosel', 'T.', ''], ['Grabec', 'I.', '']],
#  '0704.0048': [['Stroeer', 'Alexander', ''],
#   ['Veitch', 'John', ''],
#   ['Roever', 'Christian', ''],
#   ['Bloomer', 'Ed', ''],
#   ['Clark', 'James', ''],
#   ['Christensen', 'Nelson', ''],
#   ['Hendry', 'Martin', ''],
#   ['Messenger', 'Chris', ''],
#   ['Meyer', 'Renate', ''],
#   ['Pitkin', 'Matthew', ''],
#   ['Toher', 'Jennifer', ''],
#   ['Umstaetter', 'Richard', ''],
#   ['Vecchio', 'Alberto', ''],
#   ['Woan', 'Graham', '']],
#  '0704.0049': [['Øbro', 'Mikkel', '']],
#  '0704.0050': [['Kosel', 'T.', ''], ['Grabec', 'I.', '']],
#  '0704.0051': [['Cohen', 'Scott M.', '']],
#  '0704.0052': [['Jaffe', 'Arthur', '', 'Harvard University'],
#   ['Ritter', 'Gordon', '', 'Harvard University']],
#  '0704.0053': [['Youssef', 'Nabil L.', ''],
#   ['Abed', 'S. H.', ''],
#   ['Soleiman', 'A.', '']],
#  '0704.0054': [['Abu-Shammala', 'Wael', ''], ['Torchinsky', 'Alberto', '']],
#  '0704.0055': [['Ziambaras', 'Eleni', ''],
#   ['Kleis', 'Jesper', ''],
#   ['Schroder', 'Elsebeth', ''],
#   ['Hyldgaard', 'Per', '']],
#  '0704.0056': [['Prestipino', 'Santi', ''], ['Saija', 'Franz', '']],
#  '0704.0057': [['Werner', 'Philipp', ''], ['Millis', 'Andrew J.', '']],
#  '0704.0058': [['Tipler', 'Frank J.', '']],
#  '0704.0059': [['Beatty', 'T. G.', ''],
#   ['Fernandez', 'J. M.', ''],
#   ['Latham', 'D. W.', ''],
#   ['Bakos', 'G. A.', ''],
#   ['Kovacs', 'G.', ''],
#   ['Noyes', 'R. W.', ''],
#   ['Stefanik', 'R. P.', ''],
#   ['Torres', 'G.', ''],
#   ['Everett', 'M. E.', ''],
#   ['Hergenrother', 'C. W.', '']],
#  '0704.0060': [['Bertulani', 'C. A.', ''],
#   ['Cardella', 'G.', ''],
#   ['De Napoli', 'M.', ''],
#   ['Raciti', 'G.', ''],
#   ['Rapisarda', 'E.', '']],
#  '0704.0061': [['Rubin', 'Boris', '']],
#  '0704.0062': [['Šrámek', 'Rastislav', ''],
#   ['Brejová', 'Broňa', ''],
#   ['Vinař', 'Tomáš', '']],
#  '0704.0063': [['Choudhury', 'Somnath', '']],
#  '0704.0064': [['Malik', 'R. P.', '', 'Bhu']],
#  '0704.0065': [['Molev', 'A. I.', '']],
#  '0704.0066': [['Iliev',
#    'Bozhidar Z.',
#    '',
#    'Institute for Nuclear Research and Nuclear Energy,\n  Bulgarian Academy of Sciences, Sofia, Bulgaria']],
#  '0704.0067': [['Friedman', 'Lawrence H.', '']],
#  '0704.0068': [['Malesevic', 'Branko J.', '']],
#  '0704.0069': [['Robertson', 'John W.', '']],
#  '0704.0070': [['Yanzhang', 'He', ''], ['Chengguang', 'Bao', '']],
#  '0704.0071': [['Wichmann', 'S.', ''], ['Holman', 'E. W.', '']],
#  '0704.0072': [['Kosovtsov', 'Yu. N.', '']],
#  '0704.0073': [['Fujino', 'Osamu', '']],
#  '0704.0074': [['Abuhlail', 'J. Y.', ''], ['Nauman', 'S. K.', '']],
#  '0704.0075': [['Chen', 'Chong', ''],
#   ['Chen', 'Xiao-Lin', ''],
#   ['Liu', 'Xiang', ''],
#   ['Deng', 'Wei-Zhen', ''],
#   ['Zhu', 'Shi-Lin', '']],
#  '0704.0076': [['Gronau', 'Michael', '']],
#  '0704.0077': [['Abbas', 'Afsar', '']],
#  '0704.0078': [['Mars', 'Marc', ''],
#   ['Mena', 'Filipe C.', ''],
#   ['Vera', 'Raul', '']],
#  '0704.0079': [['Power', 'Stephen C.', '', 'Lancaster University'],
#   ['Solel', 'Baruch', '', 'Technion']],
#  '0704.0080': [['McLaughlin', 'Dean E.', ''], ['Fall', 'S. Michael', '']],
#  '0704.0081': [['Tolstoy', 'V. N.', '', 'INP, Moscow State University']],
#  '0704.0082': [['Kurosaki', 'Tetsuo', ''], ['Wadati', 'Miki', '']],
#  '0704.0083': [['Barvinsky', 'A. O.', '']],
#  '0704.0084': [['Fouxon', 'Itzhak', ''],
#   ['Meerson', 'Baruch', ''],
#   ['Assaf', 'Michael', ''],
#   ['Livne', 'Eli', '']],
#  '0704.0085': [['Mukhopadhyay', 'Partha', '']],
#  '0704.0086': [['Vysotsky', 'Vladislav V.', '']],
#  '0704.0087': [['Duc', 'Duong Minh', ''], ['Tuyen', 'Truong Trung', '']],
#  '0704.0088': [['Tcherniega', 'N. V.', '']],
#  '0704.0089': [['Grabec', 'I.', '']],
#  '0704.0090': [['Ingber', 'Lester', '']],
#  '0704.0091': [['Minasyan', 'Ashot', '']],
#  '0704.0092': [['Gattringer', 'Christof', ''], ['Liptak', 'Ludovit', '']],
#  '0704.0093': [['Lee', 'W. S.', ''],
#   ['Johnston', 'S.', ''],
#   ['Devereaux', 'T. P.', ''],
#   ['Shen', 'Z. -X.', '']],
#  '0704.0094': [['Zhao', 'HongSheng', '', 'SUPA, St Andrews']],
#  '0704.0095': [['Breuillard', 'Emmanuel', '']],
#  '0704.0096': [['Nucci', 'M. C.', ''], ['Leach', 'P. G. L.', '']],
#  '0704.0097': [['Kawahigashi', 'Yasuyuki', '']],
#  '0704.0098': [['Raymond', 'Jack', ''], ['Saad', 'David', '']],
#  '0704.0099': [['Audenaert', 'Koenraad M. R.', ''],
#   ['Aujla', 'Jaspal Singh', '']],
#  '0704.0100': [['Ida', 'Daisuke', ''], ['Siino', 'Masaru', '']],
#  '0704.0101': [['Di Vecchia', 'Paolo', '']],
#  '0704.0102': [['Chardin', 'Marc', ''],
#   ['Cutkosky', 'Steven Dale', ''],
#   ['Herzog', 'Juergen', ''],
#   ['Srinivasan', 'Hema', '']],
#  '0704.0103': [['Gemelli', 'Gianluca', '']],
#  '0704.0104': [['Gaiffi', 'Giovanni', ''], ['Grassi', 'Michele', '']],
#  '0704.0105': [['Entov', 'Michael', ''], ['Polterovich', 'Leonid', '']],
#  '0704.0106': [['Schafer', 'Andreas', ''],
#   ['Wang', 'Xin-Nian', ''],
#   ['Zhang', 'Ben-Wei', '']],
#  '0704.0107': [['Grabec', 'I.', '']],
#  '0704.0108': [['Gubin', 'Sergey', '']],
#  '0704.0109': [['Durgun', 'Engin', ''],
#   ['Cakir', 'Deniz', ''],
#   ['Akman', 'Nurten', ''],
#   ['Ciraci', 'Salim', '']],
#  '0704.0110': [['Goswami', 'Debashish', '']],
#  '0704.0111': [['Goswami', 'Debashish', '']],
#  '0704.0112': [['de Marrais', 'Robert P. C.', '']],
#  '0704.0113': [['Li',
#    'Xiaolin',
#    '',
#    'Department of Chemistry, Stanford University.'],
#   ['Zhang', 'Li', '', 'Department of Chemistry, Stanford University.'],
#   ['Wang', 'Xinran', '', 'Department of Chemistry, Stanford University.'],
#   ['Shimoyama', 'Iwao', '', 'Department of Chemistry, Stanford University.'],
#   ['Sun', 'Xiaoming', '', 'Department of Chemistry, Stanford University.'],
#   ['Seo', 'Won-Seok', '', 'Department of Chemistry, Stanford University.'],
#   ['Dai', 'Hongjie', '', 'Department of Chemistry, Stanford University.']],
#  '0704.0114': [['Kotov', 'Valeri N.', ''],
#   ['Yao', 'Dao-Xin', ''],
#   ['Neto', 'A. H. Castro', ''],
#   ['Campbell', 'D. K.', '']],
#  '0704.0115': [['Ando', 'Yoshifumi', '']],
#  '0704.0116': [['Cho', 'Yong Seung', ''], ['Hong', 'Soon-Tae', '']],
#  '0704.0117': [['Liu', 'T.', ''], ['Wang', 'K. L.', ''], ['Feng', 'M.', '']],
#  '0704.0118': [['Welander', 'Paul B.', ''], ['Eckstein', 'James N.', '']],
#  '0704.0119': [['Thamizhavel', 'A.', ''],
#   ['Kulkarni', 'R.', ''],
#   ['Dhar', 'S. K.', '']],
#  '0704.0120': [['Cheng', 'Xiao-Dong', ''],
#   ['He', 'Kang-Lin', ''],
#   ['Li', 'Hai-Bo', ''],
#   ['Wang', 'Yi-Fang', ''],
#   ['Yang', 'Mao-Zhi', '']],
#  '0704.0121': [['Ahn', 'Changhyun', '']],
#  '0704.0122': [['Takahashi', 'M.', ''],
#   ['Ghosh', 'Sankalpa', ''],
#   ['Mizushima', 'T.', ''],
#   ['Machida', 'K.', '']],
#  '0704.0123': [['Makovetskii', 'D. N.', '']],
#  '0704.0124': [['Coupet', 'Bernard', ''],
#   ['Sukhov', 'Alexandre', ''],
#   ['Tumanov', 'Alexander', '']],
#  '0704.0125': [['Reissig', 'Michael', ''], ['Wirth', 'Jens', '']],
#  '0704.0126': [['Yang', 'Huan', ''],
#   ['Jia', 'Ying', ''],
#   ['Shan', 'Lei', ''],
#   ['Zhang', 'Yingzi', ''],
#   ['Wen', 'Hai-Hu', ''],
#   ['Zhuang', 'Chenggang', ''],
#   ['Liu', 'Zikui', ''],
#   ['Li', 'Qi', ''],
#   ['Cui', 'Yi', ''],
#   ['Xi', 'Xiaoxing', '']],
#  '0704.0127': [['Dumas', 'Randy K.', ''],
#   ['Li', 'Chang-Peng', ''],
#   ['Roshchin', 'Igor V.', ''],
#   ['Schuller', 'Ivan K.', ''],
#   ['Liu', 'Kai', '']],
#  '0704.0128': [['Evans', 'P. A.', ''],
#   ['Beardmore', 'A. P.', ''],
#   ['Page', 'K. L.', ''],
#   ['Tyler', 'L. G.', ''],
#   ['Osborne', 'J. P.', ''],
#   ['Goad', 'M. R.', ''],
#   ["O'Brien", 'P. T.', ''],
#   ['Vetere', 'L.', ''],
#   ['Racusin', 'J.', ''],
#   ['Morris', 'D.', ''],
#   ['Burrows', 'D. N.', ''],
#   ['Capalbi', 'M.', ''],
#   ['Perri', 'M.', ''],
#   ['Gehrels', 'N.', ''],
#   ['Romano', 'P.', '']],
#  '0704.0129': [['Sorrentino', 'Alfonso', '']],
#  '0704.0130': [['Bouarroudj', 'Sofiane', ''],
#   ['Grozman', 'Pavel', ''],
#   ['Leites', 'Dimitry', '']],
#  '0704.0131': [['Zheng-Johansson', 'J. X.', '']],
#  '0704.0132': [['Khrapai', 'V. S.', ''],
#   ['Ludwig', 'S.', ''],
#   ['Kotthaus', 'J. P.', ''],
#   ['Tranitz', 'H. P.', ''],
#   ['Wegscheider', 'W.', '']],
#  '0704.0133': [['Lutz', 'D.', ''],
#   ['Sturm', 'E.', ''],
#   ['Tacconi', 'L. J.', ''],
#   ['Valiante', 'E.', ''],
#   ['Schweitzer', 'M.', ''],
#   ['Netzer', 'H.', ''],
#   ['Maiolino', 'R.', ''],
#   ['Andreani', 'P.', ''],
#   ['Shemmer', 'O.', ''],
#   ['Veilleux', 'S.', '']],
#  '0704.0134': [['Chaudhuri', 'A. K.', '']],
#  '0704.0135': [['Menicucci', 'Nicolas C.', ''], ['Milburn', 'G. J.', '']],
#  '0704.0136': [['Weng', 'Zihua', '']],
#  '0704.0137': [['Tiwari', 'S C', '']],
#  '0704.0138': [['Barausse', 'Enrico', ''],
#   ['Hughes', 'Scott A.', ''],
#   ['Rezzolla', 'Luciano', '']],
#  '0704.0139': [['Lanzoni', 'B.', ''],
#   ['Dalessandro', 'E.', ''],
#   ['Ferraro', 'F. R.', ''],
#   ['Mancini', 'C.', ''],
#   ['Beccari', 'G.', ''],
#   ['Rood', 'R. T.', ''],
#   ['Mapelli', 'M.', ''],
#   ['Sigurdsson', 'S.', '']],
#  '0704.0140': [['Cadoni', 'Mariano', '']],
#  '0704.0141': [['Molodtsov', 'S. V.', ''], ['Zinovjev', 'G. M.', '']],
#  '0704.0142': [['Kaupuzs', 'J.', '']],
#  '0704.0143': [['Molodtsov', 'S. V.', ''], ['Zinovjev', 'G. M.', '']],
#  '0704.0144': [['Podolsky', 'D.', ''], ['Enqvist', 'K.', '']],
#  '0704.0145': [['Date', 'Ghanashyam', '']],
#  '0704.0146': [['Parker', 'N. G.', ''],
#   ['Jackson', 'B.', ''],
#   ['Martin', 'A. M.', ''],
#   ['Adams', 'C. S.', '']],
#  '0704.0147': [['Sudha', '', ''],
#   ['Rao', 'A. V. Gopala', ''],
#   ['Devi', 'A. R. Usha', ''],
#   ['Rajagopal', 'A. K.', '']],
#  '0704.0148': [['Jiang', 'J. H.', ''],
#   ['Wang', 'Y. Y.', ''],
#   ['Wu', 'M. W.', '']],
#  '0704.0149': [['Gourgoulhon',
#    'Eric',
#    '',
#    'LUTH, CNRS / Observatoire de Paris / Univ. Paris 7']],
#  '0704.0150': [['Gu', 'Bo', ''], ['Su', 'Gang', '']],
#  '0704.0151': [['Grabec', 'I.', '']],
#  '0704.0152': [['Abrosimov', 'V. I.', ''],
#   ['Brink', 'D. M.', ''],
#   ['Dellafiore', 'A.', ''],
#   ['Matera', 'F.', '']],
#  '0704.0153': [['Ahmad', 'Mushfiq', '']],
#  '0704.0154': [['Eichstaedt', 'Fabian', ''],
#   ['Leupold', 'Stefan', ''],
#   ['Mosel', 'Ulrich', ''],
#   ['Muehlich', 'Pascal', '']],
#  '0704.0155': [['van der Tak', 'Floris', '', 'SRON Groningen'],
#   ['Black', 'John', '', 'Onsala'],
#   ['Schoeier', 'Fredrik', '', 'Stockholm'],
#   ['Jansen', 'David', '', 'Leiden'],
#   ['van Dishoeck', 'Ewine', '', 'Leiden']],
#  '0704.0156': [['He', 'Han', ''], ['Wang', 'Huaning', '']],
#  '0704.0157': [['de Haro', 'M. Lopez', ''],
#   ['Yuste', 'S. B.', ''],
#   ['Santos', 'A.', '']],
#  '0704.0158': [['Zhao', 'Fangcui', ''],
#   ['Yang', 'Huijie', ''],
#   ['Wang', 'Binghong', '']],
#  '0704.0159': [['Cercellier', 'H.', ''],
#   ['Monney', 'C.', ''],
#   ['Clerc', 'F.', ''],
#   ['Battaglia', 'C.', ''],
#   ['Despont', 'L.', ''],
#   ['Garnier', 'M. G.', ''],
#   ['Beck', 'H.', ''],
#   ['Patthey', 'L.', ''],
#   ['Berger', 'H.', ''],
#   ['Aebi', 'P.', '']],
#  '0704.0160': [['Stasinska', 'G.', ''],
#   ['Tenorio-Tagle', 'G.', ''],
#   ['Rodriguez', 'M.', ''],
#   ['Henney', 'W. J.', '']],
#  '0704.0161': [['Ravindran', 'T. R.', ''],
#   ['Arora', 'A. K.', ''],
#   ['Chandra', 'Sharat', ''],
#   ['Valsakumar', 'M. C.', ''],
#   ['Shekar', 'N. V. Chandra', '']],
#  '0704.0162': [['Grabec', 'I.', '']],
#  '0704.0163': [['Brommer',
#    'Peter',
#    '',
#    'Institut für Theoretische und\n  Angewandte Physik, Universität Stuttgart'],
#   ['Gähler',
#    'Franz',
#    '',
#    'Institut für Theoretische und\n  Angewandte Physik, Universität Stuttgart']],
#  '0704.0164': [['Rosati', 'Lilia', '']],
#  '0704.0165': [['Abu-Hamed', 'Mohammad', ''], ['Gelaki', 'Shlomo', '']],
#  '0704.0166': [['Garcia-Etxebarria', 'Inaki', ''],
#   ['Saad', 'Fouad', ''],
#   ['Uranga', 'Angel M.', '']],
#  '0704.0167': [['Eeg', 'Jan O.', '']],
#  '0704.0168': [['Dempsey', 'Paul', ''], ['Duffy', 'Peter', '']],
#  '0704.0169': [['Calucci', 'Giorgio', '']],
#  '0704.0170': [['Fausti', 'Daniele', ''],
#   ['Lummen', 'Tom T. A.', ''],
#   ['Angelescu', 'Cosmina', ''],
#   ['Macovez', 'Roberto', ''],
#   ['Luzon', 'Javier', ''],
#   ['Broer', 'Ria', ''],
#   ['Rudolf', 'Petra', ''],
#   ['van Loosdrecht', 'Paul H. M.', ''],
#   ['Tristan', 'Natalia', ''],
#   ['Buchner', 'Bernd', ''],
#   ['van Smaalen', 'Sander', ''],
#   ['Moller', 'Angela', ''],
#   ['Meyer', 'Gerd', ''],
#   ['Taetz', 'Timo', '']],
#  '0704.0171': [['Aharonian', 'F.', '']],
#  '0704.0172': [['Shawish', 'S. El', ''],
#   ['Ramsak', 'A.', ''],
#   ['Bonca', 'J.', '']],
#  '0704.0173': [['Takenaka', 'H.', ''], ['Singh', 'D. J.', '']],
#  '0704.0174': [['Botella',
#    'Francisco J.',
#    '',
#    'Valencia U. & Valencia U., IFIC'],
#   ['Nebot', 'Miguel', '', 'Lisbon, IST']],
#  '0704.0175': [['Amendola', 'Luca', ''],
#   ['Charmousis', 'Christos', ''],
#   ['Davis', 'Stephen C.', '']],
#  '0704.0176': [['Huang', 'Jing', ''],
#   ['Li', 'Qunxiang', ''],
#   ['Ren', 'Hao', ''],
#   ['Su', 'Haibin', ''],
#   ['Shi', 'Q. W.', ''],
#   ['Yang', 'Jinlong', '']],
#  '0704.0177': [['Greilich', 'A.', ''],
#   ['Wiemann', 'M.', ''],
#   ['Hernandez', 'F. G. G.', ''],
#   ['Yakovlev', 'D. R.', ''],
#   ['Yugova', 'I. A.', ''],
#   ['Shabaev', 'A.', ''],
#   ['Efros', 'Al. L.', ''],
#   ['Reuter', 'D.', ''],
#   ['Wieck', 'A. D.', ''],
#   ['Bayer', 'M.', '']],
#  '0704.0178': [['Holst', 'Bastian', ''],
#   ['Nettelmann', 'Nadine', ''],
#   ['Redmer', 'Ronald', '']],
#  '0704.0179': [['Zavatta', 'Alessandro', ''],
#   ['Parigi', 'Valentina', ''],
#   ['Bellini', 'Marco', '']],
#  '0704.0180': [['Rodin', 'Vadim', '']],
#  '0704.0181': [['Goh', 'Joel', ''],
#   ['Fushman', 'Ilya', ''],
#   ['Englund', 'Dirk', ''],
#   ['Vuckovic', 'Jelena', '']],
#  '0704.0182': [['Kuch', 'W.', ''],
#   ['Offi', 'F.', ''],
#   ['Chelaru', 'L. I.', ''],
#   ['Wang', 'J.', ''],
#   ['Fukumoto', 'K.', ''],
#   ['Kotsugi', 'M.', ''],
#   ['Kirschner', 'J.', ''],
#   ['Kunes', 'J.', '']],
#  '0704.0183': [['Dereli', 'G.', '', 'Yildiz Tech. Univ., Istanbul'],
#   ['Sungu', 'B.', '', 'Yildiz Tech. Univ., Istanbul']],
#  '0704.0184': [['Padovani', 'P.', '', 'ESO']],
#  '0704.0185': [['Brommer',
#    'Peter',
#    '',
#    'Institut für Theoretische und\n  Angewandte Physik, Universität Stuttgart'],
#   ['Gähler',
#    'Franz',
#    '',
#    'Institut für Theoretische und\n  Angewandte Physik, Universität Stuttgart']],
#  '0704.0186': [['Takahashi', 'Ryo', ''], ['Tanimoto', 'Morimitsu', '']],
#  '0704.0187': [['Worseck', 'G.', ''],
#   ['Fechner', 'C.', ''],
#   ['Wisotzki', 'L.', ''],
#   ["Dall'Aglio", 'A.', '']],
#  '0704.0188': [['Elliott', 'Tanya M', ''], ['Wheater', 'John F', '']],
#  '0704.0189': [['Birget', 'J. C.', '']],
#  '0704.0190': [['Konishi', 'E.', ''],
#   ['Minorikawa', 'Y.', ''],
#   ['Galkin', 'V. I.', ''],
#   ['Ishiwata', 'M.', ''],
#   ['Nakamura', 'I.', ''],
#   ['Takahashit', 'N.', ''],
#   ['Kato', 'M.', ''],
#   ['Misaki', 'A.', '']],
#  '0704.0191': [['Virnau', 'Peter', ''],
#   ['Mirny', 'Leonid A.', ''],
#   ['Kardar', 'Mehran', '']],
#  '0704.0192': [["O'Neil", 'K.', ''], ['Oey', 'S.', ''], ['Bothun', 'G.', '']],
#  '0704.0193': [['Yuan', 'Shengjun', ''],
#   ['De Raedt', 'Hans', ''],
#   ['Miyashita', 'Seiji', '']],
#  '0704.0194': [['Gurvitz', 'S. A.', ''], ['Mozyrsky', 'D.', '']],
#  '0704.0195': [['Drinfeld', 'Vladimir', ''],
#   ['Gelaki', 'Shlomo', ''],
#   ['Nikshych', 'Dmitri', ''],
#   ['Ostrik', 'Victor', '']],
#  '0704.0196': [['Piesciuk', 'Karolina', ''], ['Praszalowicz', 'Michal', '']],
#  '0704.0197': [['Schober', 'Steffen', ''], ['Bossert', 'Martin', '']],
#  '0704.0198': [['Hilario', 'L. M. Leon', ''],
#   ['Bruchhausen', 'A.', ''],
#   ['Lobos', 'A. M.', ''],
#   ['Aligia', 'A. A.', '']],
#  '0704.0199': [['Krattenthaler', 'Christian', '', 'Universität Wien'],
#   ['Müller',
#    'Thomas',
#    '',
#    'Queen Mary & Westfield College, University of London']],
#  '0704.0200': [['Schumacher', 'Martin', '']],
#  '0704.0201': [['Khongsap', 'Ta', ''], ['Wang', 'Weiqiang', '']],
#  '0704.0202': [['Perdrix', 'Simon', '']],
#  '0704.0203': [['Muench', 'August A.', ''],
#   ['Lada', 'Charles J.', ''],
#   ['Luhman', 'K. L.', ''],
#   ['Muzerolle', 'James', ''],
#   ['Young', 'Erick', '']],
#  '0704.0204': [['Pala', 'Marco G.', ''],
#   ['Governale', 'Michele', ''],
#   ['König', 'Jürgen', '']],
#  '0704.0205': [['Esposito', 'P.', ''],
#   ['Tiengo', 'A.', ''],
#   ['De Luca', 'A.', ''],
#   ['Mattana', 'F.', '']],
#  '0704.0206': [['Lepri', 'Stefano', ''], ['Giacomelli', 'Giovanni', '']],
#  '0704.0207': [['Prakash', 'M', '']],
#  '0704.0208': [['Hagge', 'Tobias J.', ''], ['Hong', 'Seung-Moon', '']],
#  '0704.0209': [['Park', 'Sangwook', '', 'Penn State'],
#   ['Burrows', 'David N.', '', 'Penn State'],
#   ['Garmire', 'Gordon P.', '', 'Penn State'],
#   ['McCray', 'Richard', '', 'Colorado'],
#   ['Racusin', 'Judith L.', '', 'Penn State'],
#   ['Zhekov', 'Svetozar A.', '', 'Space Res Inst']],
#  '0704.0210': [['Dancer', 'Andrew', ''], ['Wang', 'Mckenzie', '']],
#  '0704.0211': [['Kühn', 'Daniela', ''], ['Osthus', 'Deryk', '']],
#  '0704.0212': [['Lalak', 'Z.', ''],
#   ['Langlois', 'D.', ''],
#   ['Pokorski', 'S.', ''],
#   ['Turzynski', 'K.', '']],
#  '0704.0213': [['Narayanan', 'Ketan D. Mulmuley Hariharan', '']],
#  '0704.0214': [['Znojil', 'Miloslav', '']],
#  '0704.0215': [['Puchała', 'Zbigniew', ''], ['Rolski', 'Tomasz', '']],
#  '0704.0216': [['Mattausch', 'Alexander', ''], ['Pankratov', 'Oleg', '']],
#  '0704.0217': [['Santipach', 'Wiroonsak', ''], ['Honig', 'Michael L.', '']],
#  '0704.0218': [['Pritykin', 'Yuri', '']],
#  '0704.0219': [['Gelfand', 'Joseph D.', ''],
#   ['Gaensler', 'B. M.', ''],
#   ['Slane', 'Patrick O.', ''],
#   ['Patnaude', 'Daniel J.', ''],
#   ['Hughes', 'John P.', ''],
#   ['Camilo', 'Fernando', '']],
#  '0704.0220': [['Ulery', 'Jason Glyndwr', '', 'for the STAR Collaboration']],
#  '0704.0221': [['Krauss', 'Lawrence M.', ''], ['Scherrer', 'Robert J.', '']],
#  '0704.0222': [['Sanchez-Conde', 'Miguel A.', '']],
#  '0704.0223': [['Lou', 'Yu-Qing', ''], ['Wang', 'Wei-Gang', '']],
#  '0704.0224': [['Ulery', 'Jason Glyndwr', '', 'for the STAR Collaboration']],
#  '0704.0225': [['Kashlinsky', 'A.', ''], ['Band', 'D.', '']],
#  '0704.0226': [['Tombesi', 'F.', ''],
#   ['De Marco', 'B.', ''],
#   ['Iwasawa', 'K.', ''],
#   ['Cappi', 'M.', ''],
#   ['Dadina', 'M.', ''],
#   ['Ponti', 'G.', ''],
#   ['Miniutti', 'G.', ''],
#   ['Palumbo', 'G. G. C.', '']],
#  '0704.0227': [['Sfienti', 'C.', ''],
#   ['De Napoli', 'M.', ''],
#   ['Bianchin', 'S.', ''],
#   ['Botvina', 'A. S.', ''],
#   ['Brzychczyk', 'J.', ''],
#   ['Fevre', 'A. Le', ''],
#   ['Lukasik', 'J.', ''],
#   ['Pawlowski', 'P.', ''],
#   ['Trautmann', 'W.', ''],
#   ['Collaboration', 'the ALADiN2000', '']],
#  '0704.0228': [['Nieuwenhuizen', 'Theo M.', '']],
#  '0704.0229': [['Mulmuley', 'Ketan D.', '']],
#  '0704.0230': [['Duffard', 'R.', ''], ['Roig', 'F.', '']],
#  '0704.0231': [['Ortega-Cerda', 'Joaquim', '']],
#  '0704.0232': [['Bergbauer', 'Christoph', ''], ['Kreimer', 'Dirk', '']],
#  '0704.0233': [['Tomadin', 'Andrea', ''],
#   ['Mannella', 'Riccardo', ''],
#   ['Wimberger', 'Sandro', '']],
#  '0704.0234': [['Ghirlanda', 'G.', ''],
#   ['Nava', 'L.', ''],
#   ['Ghisellini', 'G.', ''],
#   ['Firmani', 'C.', '']],
#  '0704.0235': [['Rizzo', 'Thomas G.', '']],
#  '0704.0236': [['Gerhardt', 'Claus', '']],
#  '0704.0237': [['Mauche',
#    'Christopher W.',
#    '',
#    "Lawrence\n  Livermore Nat'l Lab."],
#   ['Liedahl', 'Duane A.', '', "Lawrence\n  Livermore Nat'l Lab."],
#   ['Akiyama', 'Shizuka', '', "Lawrence\n  Livermore Nat'l Lab."],
#   ['Plewa', 'Tomasz', '', 'University of Chicago']],
#  '0704.0238': [['Bower', 'Geoffrey C.', '', 'Berkeley'],
#   ['Bolatto', 'Alberto', '', 'Berkeley'],
#   ['Ford', 'Eric', '', 'CfA, Florida'],
#   ['Kalas', 'Paul', '', 'Berkeley'],
#   ['Ulvestad', 'Jim', '', 'NRAO']],
#  '0704.0239': [['Dzubiella', 'Joachim', '']],
#  '0704.0240': [['Son', 'D. T.', ''], ['Starinets', 'A. O.', '']],
#  '0704.0241': [['Hague', 'J. P.', '']],
#  '0704.0242': [['Fish', 'Vincent L.', '', 'NRAO']],
#  '0704.0243': [['Bauer', 'J.', ''], ['Hewson', 'A. C.', '']],
#  '0704.0244': [['Sharma', 'S.', ''],
#   ['Pittalis', 'S.', ''],
#   ['Kurth', 'S.', ''],
#   ['Shallcross', 'S.', ''],
#   ['Dewhurst', 'J. K.', ''],
#   ['Gross', 'E. K. U.', '']],
#  '0704.0245': [['Brandhuber', 'Andreas', ''],
#   ['Spence', 'Bill', ''],
#   ['Travaglini', 'Gabriele', ''],
#   ['Zoubos', 'Konstantinos', '']],
#  '0704.0246': [['Zimbovskaya', 'Natalya A.', '']],
#  '0704.0247': [['Cacciatori', 'S. L.', ''],
#   ['Caldarelli', 'M. M.', ''],
#   ['Klemm', 'D.', ''],
#   ['Mansi', 'D. S.', ''],
#   ['Roest', 'D.', '']],
#  '0704.0248': [['Weder', 'Ricardo', '']],
#  '0704.0249': [['Ortloff', 'Jutta', ''],
#   ['Balzer', 'Matthias', ''],
#   ['Potthoff', 'Michael', '']],
#  '0704.0250': [['Pankov', 'S.', ''], ['Dobrosavljevic', 'V.', '']],
#  '0704.0251': [['Gour', 'Gilad', ''], ['Wallach', 'Nolan R.', '']],
#  '0704.0252': [['Alok', 'Ashutosh Kumar', ''], ['Sankar', 'S. Uma', '']],
#  '0704.0253': [['Harvey', 'Paul M.', ''],
#   ['Rebull', 'Luisa M.', ''],
#   ['Brooke', 'Tim', ''],
#   ['Spiesman', 'William J.', ''],
#   ['Chapman', 'Nicholas', ''],
#   ['Huard', 'Tracy L.', ''],
#   ['Evans', 'Neal J.', 'II'],
#   ['Cieza', 'Lucas', ''],
#   ['Lai', 'Shih-Ping', ''],
#   ['Allen', 'Lori E.', ''],
#   ['Mundy', 'Lee G.', ''],
#   ['Padgett', 'Deborah L.', ''],
#   ['Sargent', 'Anneila I.', ''],
#   ['Stapelfeldt', 'Karl R.', ''],
#   ['Myers', 'Philip C.', ''],
#   ['van Dishoeck', 'Ewine F.', ''],
#   ['Blake', 'Geoffrey A.', ''],
#   ['Koerner', 'David W.', '']],
#  '0704.0254': [['Alves', 'Alexandre', ''], ['Eboli', 'Oscar', '']],
#  '0704.0255': [['Marin', 'Felipe', '', 'Chicago, KICP'],
#   ['Wechsler', 'Risa', '', 'KIPAC, Stanford'],
#   ['Frieman', 'Joshua', '', 'Chicago, KICP and Fermilab'],
#   ['Nichol', 'Robert', '', 'ICG, Portsmouth']],
#  '0704.0256': [['Harvey', 'Paul M.', ''], ['Oldag', 'Andrew', '']],
#  '0704.0257': [['Holm', 'Tara S.', '']],
#  '0704.0258': [['Guerra', 'Diego', ''],
#   ['Mendez-Galain', 'Ramon', ''],
#   ['Wschebor', 'Nicolas', '']],
#  '0704.0259': [['Kenyon', 'Scott J.', ''],
#   ['Bromley', 'Benjamin C.', ''],
#   ["O'Brien", 'David P.', ''],
#   ['Davis', 'Donald R.', '']],
#  '0704.0260': [['Gorbachuk', 'M. L.', ''], ['Torba', 'S. M.', '']],
#  '0704.0261': [['Randall', 'Scott W.', ''],
#   ['Markevitch', 'Maxim', ''],
#   ['Clowe', 'Douglas', ''],
#   ['Gonzalez', 'Anthony H.', ''],
#   ['Bradac', 'Marusa', '']],
#  '0704.0262': [['Argurio', 'Riccardo', ''],
#   ['Bertolini', 'Matteo', ''],
#   ['Ferretti', 'Gabriele', ''],
#   ['Lerda', 'Alberto', ''],
#   ['Petersson', 'Christoffer', '']],
#  '0704.0263': [['Eyink', 'Gregory L.', '']],
#  '0704.0264': [['Dai', 'Jian', '']],
#  '0704.0265': [['Dolcini', 'A.', ''],
#   ['Farfanelli', 'F.', ''],
#   ['Ciprini', 'S.', ''],
#   ['Treves', 'A.', ''],
#   ['Covino', 'S.', ''],
#   ['Tosti', 'G.', ''],
#   ['Pian', 'E.', ''],
#   ['Sbarufatti', 'B.', ''],
#   ['Molinari', 'E.', ''],
#   ['Chincarini', 'G.', ''],
#   ['Zerbi', 'F. M.', ''],
#   ['Malaspina', 'G.', ''],
#   ['Conconi', 'P.', ''],
#   ['Nicastro', 'L.', ''],
#   ['Palazzi', 'E.', ''],
#   ['Testa', 'V.', ''],
#   ['Vitali', 'F.', ''],
#   ['Antonelli', 'L. A.', ''],
#   ['Danziger', 'J.', ''],
#   ['Tagliaferri', 'G.', ''],
#   ['Meurs', 'E.', ''],
#   ['Vergani', 'S.', ''],
#   ['Fernandez-Soto', 'A.', ''],
#   ['Distefano', 'E.', ''],
#   ['Cutispoto', 'G.', ''],
#   ["D'Alessio", 'F.', '']],
#  '0704.0266': [['Hoffman', 'Jennifer L.', '']],
#  '0704.0267': [['Froning', 'C. S.', ''],
#   ['Robinson', 'E. L.', ''],
#   ['Bitner', 'M. A.', '']],
#  '0704.0268': [['Whitney', 'Mark', ''],
#   ['Isailovic', 'Nemanja', ''],
#   ['Patel', 'Yatish', ''],
#   ['Kubiatowicz', 'John', '']],
#  '0704.0269': [['Joshi', 'M.', ''], ['Boettcher', 'M.', '']],
#  '0704.0270': [['Bonfils', 'X.', ''],
#   ['Mayor', 'M.', ''],
#   ['Delfosse', 'X.', ''],
#   ['Forveille', 'T.', ''],
#   ['Gillon', 'M.', ''],
#   ['Perrier', 'C.', ''],
#   ['Udry', 'S.', ''],
#   ['Bouchy', 'F.', ''],
#   ['Lovis', 'C.', ''],
#   ['Pepe', 'F.', ''],
#   ['Queloz', 'D.', ''],
#   ['Santos', 'N. C.', ''],
#   ['Bertaux', 'J. -L.', '']],
#  '0704.0271': [['Brigatti', 'E.', ''],
#   ['Schwammle', 'V.', ''],
#   ['Neto', 'Minos A.', '']],
#  '0704.0272': [['Rodriguez', 'Monica Ivette', ''],
#   ['Wiklind', 'Tommy', ''],
#   ['Allen', 'Ronald J.', ''],
#   ['Escalante', 'Vladimir', ''],
#   ['Loinard', 'Laurent', '']],
#  '0704.0273': [['Cimasoni', 'David', ''], ['Reshetikhin', 'Nicolai', '']],
#  '0704.0274': [['von Hippel', 'Georg M.', '']],
#  '0704.0275': [['Bergman', 'George M.', '', 'U.C.Berkeley']],
#  '0704.0276': [['Wolleben', 'M.', '']],
#  '0704.0277': [['Kalai', 'Gil', ''], ['Meshulam', 'Roy', '']],
#  '0704.0278': [['Khavkine', 'Igor', ''], ['Christensen', 'J. Daniel', '']],
#  '0704.0279': [['Petric', 'A. O.', ''], ['Rupen', 'M. P.', '']],
#  '0704.0280': [['Webbink',
#    'Ronald F.',
#    '',
#    'University of Illinois at Urbana-Champaign']],
#  '0704.0281': [['Richard', 'Denis', '']],
#  '0704.0282': [['Bandi', 'Samuele', ''],
#   ['Stabellini', 'Luca', ''],
#   ['Conti', 'Andrea', ''],
#   ['Tralli', 'Velio', '']],
#  '0704.0283': [['Green', 'R. M.', '']],
#  '0704.0284': [['Kao', 'Hsien-chung', '']],
#  '0704.0285': [['de Heer', 'Walt A.', ''],
#   ['Berger', 'Claire', ''],
#   ['Wu', 'Xiaosong', ''],
#   ['First', 'Phillip N.', ''],
#   ['Conrad', 'Edward H.', ''],
#   ['Li', 'Xuebin', ''],
#   ['Li', 'Tianbo', ''],
#   ['Sprinkle', 'Michael', ''],
#   ['Hass', 'Joanna', ''],
#   ['Sadowski', 'Marcin L.', ''],
#   ['Potemski', 'Marek', ''],
#   ['Martinez', 'Gerard', '']],
#  '0704.0286': [['Kuchment', 'Peter', ''], ['Kunyansky', 'Leonid', '']],
#  '0704.0287': [['Parkinson', 'Pablo M. Saz', '', 'Milagro Collaboration']],
#  '0704.0288': [['Chaudhuri', 'G.', ''], ['Gupta', 'S. Das', '']],
#  '0704.0289': [['Schweikhard', 'V.', ''],
#   ['Tung', 'S.', ''],
#   ['Cornell', 'E. A.', '']],
#  '0704.0290': [['Hurley', 'Jarrod R.', ''],
#   ['Aarseth', 'Sverre J.', ''],
#   ['Shara', 'Michael M.', '']],
#  '0704.0291': [['Jeppesen', 'M.', ''],
#   ['Dugué', 'J.', ''],
#   ['Dennis', 'G. R.', ''],
#   ['Johnsson', 'M. T.', ''],
#   ['Figl', 'C.', ''],
#   ['Robins', 'N. P.', ''],
#   ['Close', 'J. D.', '']],
#  '0704.0292': [['Salam', 'Gavin P.', ''], ['Soyez', 'Gregory', '']],
#  '0704.0293': [['Dubynskiy', 'S.', ''],
#   ['Yaouanc', 'A. Le', ''],
#   ['Oliver', 'L.', ''],
#   ['Raynal', 'J. -C.', ''],
#   ['Voloshin', 'M. B.', '']],
#  '0704.0294': [['Ward', 'B. F. L.', ''], ['Yost', 'S. A.', '']],
#  '0704.0295': [['Basu', 'Saugata', '']],
#  '0704.0296': [['Bars', 'Itzhak', ''], ['Orcal', 'Bora', '']],
#  '0704.0297': [['Yoon', 'Sung-Chul', ''],
#   ['Podsiadlowski', 'Philipp', ''],
#   ['Rosswog', 'Stephan', '']],
#  '0704.0298': [['Grushka', 'Ya.', ''], ['Torba', 'S.', '']],
#  '0704.0299': [['Alexander', 'Stephon', ''], ['Yunes', 'Nicolas', '']],
#  '0704.0300': [['Purewal', 'Meninder', ''],
#   ['Hong', 'Byung Hee', ''],
#   ['Ravi', 'Anirudhh', ''],
#   ['Chandra', 'Bhupesh', ''],
#   ['Hone', 'James', ''],
#   ['Kim', 'Philip', '']],
#  '0704.0301': [['Kawamura', 'Akitoshi', '']],
#  '0704.0302': [['Wang', 'Li', ''], ['Yang', 'Lijian', '']],
#  '0704.0303': [['BenZvi', 'S. Y.', ''],
#   ['Connolly', 'B. M.', ''],
#   ['Matthews', 'J. A. J.', ''],
#   ['Prouza', 'M.', ''],
#   ['Visbal', 'E. F.', ''],
#   ['Westerhoff', 'S.', '']],
#  '0704.0304': [['Gershenson', 'Carlos', '']],
#  '0704.0305': [['Guo', 'Yongxing', ''],
#   ['Liu', 'Yifeng', ''],
#   ['Tang', 'Jay X.', ''],
#   ['Valles', 'James M.', 'Jr']],
#  '0704.0306': [['Mei', 'D. -M.', ''],
#   ['Elliott', 'S. R.', ''],
#   ['Hime', 'A.', ''],
#   ['Gehman', 'V.', ''],
#   ['Kazkaz', 'K.', '']],
#  '0704.0307': [['Jensen',
#    'Eric L. N.',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Dhital',
#    'Saurav',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Stassun',
#    'Keivan G.',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Patience',
#    'Jenny',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Herbst',
#    'William',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Walter',
#    'Frederick M.',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Simon',
#    'Michal',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   ['Basri',
#    'Gibor',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley'],
#   [';',
#    '',
#    '',
#    '1 - Swarthmore College; 2 - Vanderbilt; 3 - Caltech; 4\n  - Wesleyan University; 5 - SUNY Stony Brook; 6 - UC Berkeley']],
#  '0704.0308': [['Deng', 'Ke', ''],
#   ['Zhao', 'Heping', ''],
#   ['Li', 'Dejun', '']],
#  '0704.0309': [['Zhu', 'Guohun', '']],
#  '0704.0310': [['Liu', 'Xiang', '', 'Urumqi\n  Observatory, NAOC'],
#   ['Cui', 'Lang', '', 'Urumqi\n  Observatory, NAOC'],
#   ['Luo', 'Wen-Feng', '', 'Urumqi\n  Observatory, NAOC'],
#   ['Shi', 'Wei-Zhao', '', 'Urumqi\n  Observatory, NAOC'],
#   ['Song', 'Hua-Gang', '', 'Urumqi\n  Observatory, NAOC']],
#  '0704.0311': [['Kirtley', 'John R.', ''],
#   ['Deng', 'Zhifeng', ''],
#   ['Luan', 'Lan', ''],
#   ['Yenilmez', 'Erhan', ''],
#   ['Dai', 'Hongjie', ''],
#   ['Moler', 'Kathryn A.', '']],
#  '0704.0312': [['Francis', 'Matthew J.', ''],
#   ['Lewis', 'Geraint F.', ''],
#   ['Linder', 'Eric V.', '']],
#  '0704.0313': [['Hayashi', 'Yuta', ''], ['Ogata', 'Masao', '']],
#  '0704.0314': [['Baukh', 'Viktor', ''],
#   ['Zhuk', 'Alexander', ''],
#   ['Kahniashvili', 'Tina', '']],
#  '0704.0315': [['Gasanenko', 'Vitalii A.', '']],
#  '0704.0316': [['Graham', 'Alister W.', ''],
#   ['Driver', 'Simon P.', ''],
#   ['Allen', 'Paul D.', ''],
#   ['Liske', 'Jochen', '']],
#  '0704.0317': [['Wylie', 'William', '']],
#  '0704.0318': [['Biswas', 'Subhrajyoti', ''],
#   ['Dutt-Mazumder', 'Abhee K.', '']],
#  '0704.0319': [['Ding', 'Guo-Hui', ''], ['Dong', 'Bing', '']],
#  '0704.0320': [['Mainardi', 'Francesco', ''],
#   ['Paradisi', 'Paolo', ''],
#   ['Gorenflo', 'Rudolf', '']],
#  '0704.0321': [['Maiti', 'Kalobaran', '']],
#  '0704.0322': [['Liu', 'Quan-Xing', ''],
#   ['Sun', 'Gui-Quan', ''],
#   ['Li', 'Bai-Lian', ''],
#   ['Jin', 'Zhen', '']],
#  '0704.0323': [['Dang', 'Gui-Fang', ''], ['Fan', 'Heng', '']],
#  '0704.0324': [['Pravda-Starov', 'Karel', '']],
#  '0704.0325': [['Grenard', 'Vincent', '', 'Phys-ENS'],
#   ['Garnier', 'Nicolas', '', 'Phys-ENS'],
#   ['Naert', 'Antoine', '', 'Phys-ENS']],
#  '0704.0326': [['Mathai', 'A. M.', ''], ['Haubold', 'H. J.', '']],
#  '0704.0327': [['Maiti', 'Kalobaran', ''],
#   ['Singh', 'Ravi Shankar', ''],
#   ['Medicherla', 'V. R. R.', '']],
#  '0704.0328': [['Ham', 'S. W.', ''],
#   ['Yoo', 'E. J.', ''],
#   ['OH', 'S. K.', '']],
#  '0704.0329': [['Haubold', 'H. J.', ''],
#   ['Mathai', 'A. M.', ''],
#   ['Saxena', 'R. K.', '']],
#  '0704.0330': [['Splittorff', 'K.', ''], ['Verbaarschot', 'J. J. M.', '']],
#  '0704.0331': [['Jestin', 'J. -L.', '', 'IHES'], ['Soule', 'C.', '', 'IHES']],
#  '0704.0332': [['Gerrard', 'M. B.', ''], ['Sumner', 'T. J.', '']],
#  '0704.0333': [['Cappelluti', 'E.', ''],
#   ['Ciuchi', 'S.', ''],
#   ['Fratini', 'S.', '']],
#  '0704.0334': [['Padmanabhan', 'J.', ''],
#   ['Parthasarathi', 'R.', ''],
#   ['Elango', 'M.', ''],
#   ['Subramanian', 'V.', ''],
#   ['Krishnamoorthy', 'B. S.', ''],
#   ['Gutierrez-Oliva', 'S.', ''],
#   ['Toro-Labbe', 'A.', ''],
#   ['Roy', 'D. R.', ''],
#   ['Chattaraj', 'P. K.', '']],
#  '0704.0335': [['Pagès', 'Gilles', '', 'PMA, LSProba'],
#   ['Panloup', 'Fabien', '', 'PMA']],
#  '0704.0336': [['Karvonen', 'J. T.', ''], ['Maasilta', 'I. J.', '']],
#  '0704.0337': [['Golse', 'François', '', 'CMLS-EcolePolytechnique, LJLL'],
#   ['Mahalov', 'Alex', ''],
#   ['Nicolaenko', 'Basil', '']],
#  '0704.0338': [['Bec', 'Sandrine', '', 'LTDS'],
#   ['Tonck', 'André', '', 'LTDS'],
#   ['Georges', 'Jean-Marie', '', 'LTDS'],
#   ['Roper', 'Glyn W.', '', 'SHELL']],
#  '0704.0339': [['Fonda', 'Enrico', ''],
#   ['Tessarotto', 'Massimo', ''],
#   ['Ellero', 'Marco', '']],
#  '0704.0340': [['Kien', 'Fam Le', ''],
#   ['Gupta', 'S. Dutta', ''],
#   ['Hakuta', 'K.', '']],
#  '0704.0341': [['Ermolaev', 'B. I.', ''],
#   ['Greco', 'M.', ''],
#   ['Troyan', 'S. I.', '']],
#  '0704.0342': [['Dugmore', 'B.', ''], ['Ntumba', 'PP.', '']],
#  '0704.0343': [['Baumgartl', 'Jörg', ''],
#   ['Dullens', 'Roel P. A.', ''],
#   ['Dijkstra', 'Marjolein', ''],
#   ['Roth', 'Roland', ''],
#   ['Bechinger', 'Clemens', '']],
#  '0704.0344': [['Maraschi', 'L.', ''],
#   ['Ghisellini', 'G.', ''],
#   ['Tavecchio', 'F.', '']],
#  '0704.0345': [['Wang', 'Bing', ''], ['Kim', 'Beom Jun', '']],
#  '0704.0346': [['Hamaguchi', 'Kenji', ''],
#   ['team', 'the Suzaku Eta Carinae', ''],
#   ['team', 'the Carinae D-1', '']],
#  '0704.0347': [['Chihara', 'Hiroyuki', '']],
#  '0704.0348': [['Stasinska', 'G.', '']],
#  '0704.0349': [['Izmestiev', 'Ivan', '']],
#  '0704.0350': [['Fornasier', 'S.', ''],
#   ['Dotto', 'E.', ''],
#   ['Hainaut', 'O.', ''],
#   ['Marzari', 'F.', ''],
#   ['Boehnhardt', 'H.', ''],
#   ['De Luise', 'F.', ''],
#   ['Barucci', 'M. A.', '']],
#  '0704.0351': [['Kunert-Bajraszewska', 'Magdalena', ''],
#   ['Marecki', 'Andrzej', '']],
#  '0704.0352': [['Chigvinadze', 'J. G.', ''],
#   ['Acrivos', 'J. V.', ''],
#   ['Ashimov', 'S. M.', ''],
#   ['Iashvili', 'A. A.', ''],
#   ['Machaidze', 'T. V.', ''],
#   ['Wolf', 'Th.', '']],
#  '0704.0353': [['Alberto', 'P.', ''],
#   ['de Castro', 'A. S.', ''],
#   ['Malheiro', 'M.', '']],
#  '0704.0354': [['Podolsky', 'D.', '']],
#  '0704.0355': [['Ducourant', 'C.', ''],
#   ['Teixeira', 'R.', ''],
#   ['Hambly', 'N. C.', ''],
#   ['Oppenheimer', 'B. R.', ''],
#   ['Hawkins', 'M. R. S.', ''],
#   ['Rapaport', 'M.', ''],
#   ['Modolo', 'J.', ''],
#   ['Lecampion', 'J. F.', '']],
#  '0704.0356': [['Cerdá-Durán', 'Pablo', ''],
#   ['Quilis', 'Vicent', ''],
#   ['Font', 'José A.', '']],
#  '0704.0357': [['Szollosi', 'Gergely J', ''], ['Derenyi', 'Imre', '']],
#  '0704.0358': [['Paradisi', 'Paride', '']],
#  '0704.0359': [['Van Khue', 'Nguyen', ''], ['Hiep', 'Pham Hoang', '']],
#  '0704.0360': [['Zaqarashvili', 'T. V.', ''], ['Murawski', 'K', '']],
#  '0704.0361': [['Chatzigeorgiou', 'Ioannis', ''],
#   ['Rodrigues', 'Miguel R. D.', ''],
#   ['Wassell', 'Ian J.', ''],
#   ['Carrasco', 'Rolando', '']],
#  '0704.0362': [['Colomo', 'F.', ''], ['Pronko', 'A. G.', '']],
#  '0704.0363': [['Field', 'J. H.', '']],
#  '0704.0364': [['Vasseur', 'G.', '']],
#  '0704.0365': [['Hague', 'J. P.', '']],
#  '0704.0366': [['Diaz', 'Pablo', ''], ['Segui', 'Antonio', '']],
#  '0704.0367': [['Ita', 'Eyo Eyo', 'III']],
#  '0704.0368': [['Pashkin', 'A.', ''],
#   ['Thirunavukkuarasu', 'K.', ''],
#   ['Mathis', 'Y. -L.', ''],
#   ['Kang', 'W.', ''],
#   ['Kuntscher', 'C. A.', '']],
#  '0704.0369': [['Honda', 'Minako', ''],
#   ['Kao', 'Yee', ''],
#   ['Okamura', 'Naotoshi', ''],
#   ['Pronin', 'Alexey', ''],
#   ['Takeuchi', 'Tatsu', '']],
#  '0704.0370': [['Boulle', 'O.', ''],
#   ['Cros', 'V.', ''],
#   ['Grollier', 'J.', ''],
#   ['Pereira', 'L. G.', ''],
#   ['Deranlot', 'C.', ''],
#   ['Petroff', 'F.', ''],
#   ['Faini', 'G.', ''],
#   ['Barnas', 'J.', ''],
#   ['Fert', 'A.', '']],
#  '0704.0371': [['Kremer', 'G. M.', '']],
#  '0704.0372': [['Site', 'L. Delle', '']],
#  '0704.0373': [['Roy', 'Utpal', ''],
#   ['Ghosh', 'Suranjana', ''],
#   ['Shreecharan', 'T.', ''],
#   ['Bhattacharya', 'Kaushik', '']],
#  '0704.0374': [['Zon', 'Boris A.', ''], ['Kretinin', 'Igor Yu.', '']],
#  '0704.0375': [['Gueniche', 'Hadj-Ali', '', 'DCPR'],
#   ['Glaude', 'Pierre-Alexandre', '', 'DCPR'],
#   ['Dayma', 'Guillaume', '', 'DCPR'],
#   ['Fournet', 'René', '', 'DCPR'],
#   ['Battin-Leclerc', 'Frédérique', '', 'DCPR']],
#  '0704.0376': [['Parodi', 'Daniele', ''],
#   ['Sassetti', 'Maura', ''],
#   ['Solinas', 'Paolo', ''],
#   ['Zanghì', 'Nino', '']],
#  '0704.0377': [['Binosi', 'Daniele', '', 'ECT*, Trento'],
#   ['Pascalutsa', 'Vladimir', '', 'ECT*, Trento &\n  Mainz U.']],
#  '0704.0378': [['Duits', 'Maurice', ''], ['Kuijlaars', 'Arno B. J.', '']],
#  '0704.0379': [['Virnau', 'P.', ''],
#   ['Kardar', 'M.', ''],
#   ['Kantor', 'Y.', '']],
#  '0704.0380': [['Git', 'Y.', ''],
#   ['Harris', 'J. W.', ''],
#   ['Harris', 'S. C.', '']],
#  '0704.0381': [['Angus', 'Garry W.', '', 'St. Andrews'],
#   ['McGaugh', 'Stacy S.', '', 'Maryland']],
#  '0704.0382': [['Hamidoune', 'Yahya Ould', ''],
#   ['Serra', 'Oriol', ''],
#   ['Zemor', 'Gilles', '']],
#  '0704.0383': [['Prasad', 'Rajendra', '']],
#  '0704.0384': [['Artemenkov', 'D. A.', ''],
#   ['Shchedrina', 'T. V.', ''],
#   ['Stanoeva', 'R.', ''],
#   ['Zarubin', 'P. I.', '']],
#  '0704.0385': [['Ogren', 'M.', ''], ['Heiselberg', 'H.', '']],
#  '0704.0386': [['Laloë', 'Franck', '', 'LKB - Lhomond'],
#   ['Mullin', 'William J.', '', 'UMASS']],
#  '0704.0387': [['Eisenbeiss', 'T.', ''],
#   ['Seifahrt', 'A.', ''],
#   ['Mugrauer', 'M.', ''],
#   ['Schmidt', 'T. O. B.', ''],
#   ['Neuhaeuser', 'R.', ''],
#   ['Roell', 'T.', '']],
#  '0704.0388': [['Donini', 'A.', ''],
#   ['Maltoni', 'M.', ''],
#   ['Meloni', 'D.', ''],
#   ['Migliozzi', 'P.', ''],
#   ['Terranova', 'F.', '']],
#  '0704.0389': [['Flanagan', 'Eanna E.', ''], ['Hinderer', 'Tanja', '']],
#  '0704.0390': [['Troubetzkoy', 'Serge', '', 'CPT, Iml, Frumam']],
#  '0704.0391': [['Kozlov', 'G. G.', '']],
#  '0704.0392': [['Kaiser', 'Marcus', ''],
#   ['Martin', 'Robert', ''],
#   ['Andras', 'Peter', ''],
#   ['Young', 'Malcolm P.', '']],
#  '0704.0393': [['Hendy', 'S. C.', '']],
#  '0704.0394': [['Jaśkiewicz', 'Anna', '']],
#  '0704.0395': [['Liu', 'Xin', ''],
#   ['Xiao', 'Zhen-Jun', ''],
#   ['Wang', 'Hui-Sheng', '']],
#  '0704.0396': [['Cha', 'Min-Chul', ''], ['Lee', 'Ji-Woo', '']],
#  '0704.0397': [['Nielsen', 'Anne E. B.', ''], ['Molmer', 'Klaus', '']],
#  '0704.0398': [['Dennert', 'Florian', ''], ['Grübel', 'Rudolf', '']],
#  '0704.0399': [['Clement', 'G.', ''],
#   ['Fabris', 'J. C.', ''],
#   ['Marques', 'G. T.', '']],
#  '0704.0400': [['Beisert', 'Niklas', '']],
#  '0704.0401': [['Lançon', 'A.', ''],
#   ['Gallagher', 'J. S.', ''],
#   ['de Grijs', 'R.', ''],
#   ['Hauschildt', 'P.', ''],
#   ['Ladjal', 'D.', ''],
#   ['Mouhcine', 'M.', ''],
#   ['Smith', 'L. J.', ''],
#   ['Wood', 'P. R.', ''],
#   ['Schreiber', 'N. Förster', '']],
#  '0704.0402': [['Li', 'Yi', ''], ['Zhao', 'Chunshan', '']],
#  '0704.0403': [['Shields', 'Andrew J', '']],
#  '0704.0404': [['Kaidalov', 'A. B.', ''], ['Vysotsky', 'M. I.', '']],
#  '0704.0405': [['Kang', 'W.', ''], ['Williams', 'R. J.', '']],
#  '0704.0406': [['Heidarian', 'Dariush', ''], ['Sorella', 'Sandro', '']],
#  '0704.0407': [['Avancini', 'S. S.', ''],
#   ['Marinelli', 'J. R.', ''],
#   ['Menezes', 'D. P.', ''],
#   ['de Moraes', 'M. M. W.', ''],
#   ['Providência', 'C.', '']],
#  '0704.0408': [['Viljas', 'J. K.', ''],
#   ['Pauly', 'F.', ''],
#   ['Cuevas', 'J. C.', '']],
#  '0704.0409': [['Levkov', 'D. G.', ''],
#   ['Panin', 'A. G.', ''],
#   ['Sibiryakov', 'S. M.', '']],
#  '0704.0410': [['Deacon', 'R. S.', ''],
#   ['Chuang', 'K-C.', ''],
#   ['Nicholas', 'R. J.', ''],
#   ['Novoselov', 'K. S.', ''],
#   ['Geim', 'A. K.', '']],
#  '0704.0411': [['Xu', 'Zhiping', '']],
#  '0704.0412': [['Hertweck', 'Martin', '']],
#  '0704.0413': [['Kojo', 'Toru', ''],
#   ['Jido', 'Daisuke', ''],
#   ['Hayashigaki', 'Arata', '']],
#  '0704.0414': [['Moreau', 'Antoine', '', 'LASMEA'],
#   ['Felbacq', 'Didier', '', 'GES']],
#  '0704.0415': [['Raichev', 'O. E.', '']],
#  '0704.0416': [['Schmithuesen', 'Gabriela', '']],
#  '0704.0417': [['Baumgartner', 'Bernhard', '']],
#  '0704.0418': [['Lin', 'Yu-Cheng', ''],
#   ['Igloi', 'Ferenc', ''],
#   ['Rieger', 'Heiko', '']],
#  '0704.0419': [['Choi', 'H. C.', ''],
#   ['Masuhara', 'N.', ''],
#   ['Moon', 'B. H.', ''],
#   ['Bhupathi', 'P.', ''],
#   ['Meisel', 'M. W.', ''],
#   ['Lee', 'Y.', ''],
#   ['Mulders', 'N.', ''],
#   ['Higashitani', 'S.', ''],
#   ['Miura', 'M.', ''],
#   ['Nagai', 'K.', '']],
#  '0704.0420': [['McCartor', 'Donald', '']],
#  '0704.0421': [['Urosevic', 'D.', ''],
#   ['Vukotic', 'B.', ''],
#   ['Arbutina', 'B.', ''],
#   ['Ilic', 'D.', '']],
#  '0704.0422': [['Bianucci', 'Pablo', ''],
#   ['Fietz', 'Chris', ''],
#   ['Robertson', 'John W.', ''],
#   ['Shvets', 'Gennady', ''],
#   ['Shih', 'Chih-Kang', '']],
#  '0704.0423': [['Lee', 'H. S.', ''],
#   ['Bhang', 'H. C.', ''],
#   ['Choi', 'J. H.', ''],
#   ['Dao', 'H.', ''],
#   ['Hahn', 'I. S.', ''],
#   ['Hwang', 'M. J.', ''],
#   ['Jung', 'S. W.', ''],
#   ['Kang', 'W. G.', ''],
#   ['Kim', 'D. W.', ''],
#   ['Kim', 'H. J.', ''],
#   ['Kim', 'S. C.', ''],
#   ['Kim', 'S. K.', ''],
#   ['Kim', 'Y. D.', ''],
#   ['Kwak', 'J. W.', ''],
#   ['Kwon', 'Y. J.', ''],
#   ['Lee', 'J.', ''],
#   ['Lee', 'J. H.', ''],
#   ['Lee', 'J. I.', ''],
#   ['Lee', 'M. J.', ''],
#   ['Lee', 'S. J.', ''],
#   ['Li', 'J.', ''],
#   ['Li', 'X.', ''],
#   ['Li', 'Y. J.', ''],
#   ['Myung', 'S. S.', ''],
#   ['Ryu', 'S.', ''],
#   ['So', 'J. H.', ''],
#   ['Yue', 'Q.', ''],
#   ['Zhu', 'J. J.', '']],
#  '0704.0424': [['Luo', 'Xiao-Feng', ''],
#   ['Dong', 'Xin', ''],
#   ['Shao', 'Ming', ''],
#   ['Wu', 'Ke-Jun', ''],
#   ['Li', 'Cheng', ''],
#   ['Chen', 'Hong-Fang', ''],
#   ['Xu', 'Hu-Shan', '']],
#  '0704.0425': [['Gleim', 'Tobias', '']],
#  '0704.0426': [['Chuzhoy', 'Leonid', ''],
#   ['Kuhlen', 'Michael', ''],
#   ['Shapiro', 'Paul R.', '']],
#  '0704.0427': [['Hasenbusch', 'Martin', ''],
#   ['Toldin', 'Francesco Parisen', ''],
#   ['Pelissetto', 'Andrea', ''],
#   ['Vicari', 'Ettore', '']],
#  '0704.0428': [['Ciardi', 'David R.', ''], ['Martin', 'Cynthia Gomez', '']],
#  '0704.0429': [['Ao', 'P.', '']],
#  '0704.0430': [['Duistermaat', 'J. J.', ''], ['Pelayo', 'A.', '']],
#  '0704.0431': [['Zink', 'Burkhard', ''],
#   ['Stergioulas', 'Nikolaos', ''],
#   ['Hawke', 'Ian', ''],
#   ['Ott', 'Christian D.', ''],
#   ['Schnetter', 'Erik', ''],
#   ['Mueller', 'Ewald', '']],
#  '0704.0432': [['Akman', 'Fusun', ''], ['Ionescu', 'Lucian M.', '']],
#  '0704.0433': [['De Nicola', 'Antonio', ''],
#   ['Tulczyjew', 'Wlodzimierz M.', '']],
#  '0704.0434': [['Berejnov', 'Viatcheslav V.', '']],
#  '0704.0435': [['Pravda', 'Vojtech', ''],
#   ['Pravdova', 'Alena', ''],
#   ['Ortaggio', 'Marcello', '']],
#  '0704.0436': [['Gu', 'Ying-Qiu', ''], ['Li', 'Ta-tsien', '']],
#  '0704.0437': [['CLEO Collaboration', '', ''], ['Pedlar', 'T. K.', '']],
#  '0704.0438': [['Graesser', 'Michael L.', '']],
#  '0704.0439': [['Averin', 'Dmitri V.', ''], ['Nesteroff', 'James A.', '']],
#  '0704.0440': [['Damski', 'Bogdan', ''], ['Zurek', 'Wojciech H.', '']],
#  '0704.0441': [['Setiawan', 'J.', ''],
#   ['Weise', 'P.', ''],
#   ['Henning', 'Th.', ''],
#   ['Launhardt', 'R.', ''],
#   ['Müller', 'A.', ''],
#   ['Rodmann', 'J.', '']],
#  '0704.0442': [['Ciattoni', 'Alessandro', ''], ['Conti', 'Claudio', '']],
#  '0704.0443': [['Lensky', 'V.', ''],
#   ['Baru', 'V.', ''],
#   ['Epelbaum', 'E.', ''],
#   ['Hanhart', 'C.', ''],
#   ['Haidenbauer', 'J.', ''],
#   ['Kudryavtsev', 'A.', ''],
#   ['Meißner', 'Ulf-G.', '']],
#  '0704.0444': [['Bourjaily', 'Jacob L.', '']],
#  '0704.0445': [['Bourjaily', 'Jacob L.', '']],
#  '0704.0446': [['Carnovale', 'Giovanna', ''], ['Polizzi', 'Francesco', '']],
#  '0704.0447': [['Christensson', 'J.', ''],
#   ['Bargi', 'S.', ''],
#   ['Karkkainen', 'K.', ''],
#   ['Yu', 'Y.', ''],
#   ['Kavoulakis', 'G. M.', ''],
#   ['Manninen', 'M.', ''],
#   ['Reimann', 'S. M.', '']],
#  '0704.0448': [['Edgar', 'R. G.', '']],
#  '0704.0449': [['Braun', 'Volker', ''],
#   ['Kreuzer', 'Maximilian', ''],
#   ['Ovrut', 'Burt A.', ''],
#   ['Scheidegger', 'Emanuel', '']],
#  '0704.0450': [['Aguiar', 'M. C. O.', ''],
#   ['Dobrosavljevic', 'V.', ''],
#   ['Abrahams', 'E.', ''],
#   ['Kotliar', 'G.', '']],
#  '0704.0451': [['Ward', 'D. R.', ''],
#   ['Grady', 'N. K.', ''],
#   ['Levin', 'C. S.', ''],
#   ['Halas', 'N. J.', ''],
#   ['Wu', 'Y.', ''],
#   ['Nordlander', 'P.', ''],
#   ['Natelson', 'D.', '']],
#  '0704.0452': [['Chang', 'Chulhoon', ''], ['Cui', 'Wei', '']],
#  '0704.0453': [['Richard', 'P.', ''],
#   ['Neupane', 'M.', ''],
#   ['Xu', 'Y. -M.', ''],
#   ['Fournier', 'P.', ''],
#   ['Li', 'S.', ''],
#   ['Dai', 'Pengcheng', ''],
#   ['Wang', 'Z.', ''],
#   ['Ding', 'H.', '']],
#  '0704.0454': [['Bennett', 'D. P.', ''],
#   ['Anderson', 'J.', ''],
#   ['Beaulieu', 'J. -P.', ''],
#   ['Bond', 'I.', ''],
#   ['Cheng', 'E.', ''],
#   ['Cook', 'K.', ''],
#   ['Friedman', 'S.', ''],
#   ['Gaudi', 'B. S.', ''],
#   ['Gould', 'A.', ''],
#   ['Jenkins', 'J.', ''],
#   ['Kimble', 'R.', ''],
#   ['Lin', 'D.', ''],
#   ['Rich', 'M.', ''],
#   ['Sahu', 'K.', ''],
#   ['Tenerelli', 'D.', ''],
#   ['Udalski', 'A.', ''],
#   ['Yock', 'P.', '']],
#  '0704.0455': [['Kraus', 'Adam L.', '', 'Caltech'],
#   ['Hillenbrand', 'Lynne A.', '', 'Caltech']],
#  '0704.0456': [['Arteaga', 'Daniel', '']],
#  '0704.0457': [['Blencowe', 'M. P.', ''], ['Buks', 'E.', '']],
#  '0704.0458': [['Brown', 'J. C.', ''],
#   ['Haverkorn', 'M.', ''],
#   ['Gaensler', 'B. M.', ''],
#   ['Taylor', 'A. R.', ''],
#   ['Bizunok', 'N. S.', ''],
#   ['McClure-Griffiths', 'N. M.', ''],
#   ['Dickey', 'J. M.', ''],
#   ['Green', 'A. J.', '']],
#  '0704.0459': [['Hamidoune', 'Yahya Ould', '']],
#  '0704.0460': [['Pepper', 'Joshua', ''],
#   ['Pogge', 'Richard W.', ''],
#   ['DePoy', 'D. L.', ''],
#   ['Marshall', 'J. L.', ''],
#   ['Stanek', 'K. Z.', ''],
#   ['Stutz', 'Amelia M.', ''],
#   ['Poindexter', 'Shawn', ''],
#   ['Siverd', 'Robert', ''],
#   ["O'Brien", 'Thomas P.', ''],
# ...
#   ['Bolatto', 'Alberto', ''],
#   ['Weiss', 'Axel', '']],
#  '0704.0863': [['Han', 'Z.', ''],
#   ['Podsiadlowski', 'Ph.', ''],
#   ['Lynas-Gray', 'A. E.', '']],
#  '0704.0864': [['Bagoly', 'Z.', ''],
#   ['Csabai', 'I.', ''],
#   ['Meszaros', 'A.', ''],
#   ['Meszaros', 'P.', ''],
#   ['Horvath', 'I.', ''],
#   ['Balazs', 'L. G.', ''],
#   ['Vavrek', 'R.', '']],
#  '0704.0865': [['Rugina', 'Ana-Elena', '', 'LAAS'],
#   ['Kanoun', 'Karama', '', 'LAAS'],
#   ['Kaaniche', 'Mohamed', '', 'LAAS']],
#  '0704.0866': [['Benelkourchi', 'S.', ''],
#   ['Guedj', 'V.', ''],
#   ['Zeriahi', 'A.', '']],
#  '0704.0867': [['Situ', 'Shuping', ''],
#   ['He', 'Yanzhang', ''],
#   ['Bao', 'Chengguang', '']],
#  '0704.0868': [['Climente', 'Juan I.', ''],
#   ['Bertoni', 'Andrea', ''],
#   ['Goldoni', 'Guido', ''],
#   ['Rontani', 'Massimo', ''],
#   ['Molinari', 'Elisa', '']],
#  '0704.0869': [['Golinelli', 'O.', '', 'Cea Saclay, France'],
#   ['Mallick', 'K.', '', 'Cea Saclay, France']],
#  '0704.0870': [['Bessonov',
#    'E. G.',
#    '',
#    'Lebedev Phys. Inst. RAS, Moscow,\n  Russia'],
#   ['Gorbunkov', 'M. V.', '', 'Lebedev Phys. Inst. RAS, Moscow,\n  Russia'],
#   ['Mikhailichenko', 'A. A.', '', 'Cornell University, Ithaca, NY, U.S.A.']],
#  '0704.0871': [['Gabanyi', 'K. E.', ''],
#   ['Marchili', 'N.', ''],
#   ['Krichbaum', 'T. P.', ''],
#   ['Britzen', 'S.', ''],
#   ['Fuhrmann', 'L.', ''],
#   ['Witzel', 'A.', ''],
#   ['Zensus', 'J. A.', ''],
#   ['Muller', 'P.', ''],
#   ['Liu', 'X.', ''],
#   ['Song', 'H. G.', ''],
#   ['Han', 'J. L.', ''],
#   ['Sun', 'X. H.', '']],
#  '0704.0872': [['Veselic', 'K.', '']],
#  '0704.0873': [['Greaves', 'J. S.', ''],
#   ['Fischer', 'D. A.', ''],
#   ['Wyatt', 'M. C.', ''],
#   ['Beichman', 'C. A.', ''],
#   ['Bryden', 'G.', '']],
#  '0704.0874': [['Farkas', 'Gavril', '']],
#  '0704.0875': [['Tarasov', 'Boris V.', '']],
#  '0704.0876': [['Schachermayer', 'Walter', ''],
#   ['Schmock', 'Uwe', ''],
#   ['Teichmann', 'Josef', '']],
#  '0704.0877': [['Mannucci', 'F.', ''],
#   ['Panagia', 'N.', ''],
#   ['Della Valle', 'M.', '']],
#  '0704.0878': [['Juhin', 'Amélie', '', 'IMPMC'],
#   ['Calas', 'Georges', '', 'IMPMC'],
#   ['Cabaret', 'Delphine', '', 'IMPMC'],
#   ['Galoisy', 'Laurence', '', 'IMPMC'],
#   ['Hazemann', 'Jean-Louis', '']],
#  '0704.0879': [['Kaaniche', 'Mohamed', '', 'LAAS'],
#   ['Romano', 'Luigi', '', 'UIUC'],
#   ['Kalbarczyk', 'Zbigniew', '', 'UIUC'],
#   ['Iyer', 'Ravishankar', '', 'UIUC'],
#   ['Karcich', 'Rick', '', 'STORAGETEK']],
#  '0704.0880': [['Wang', 'Q. A.', '', 'ISMANS'],
#   ['Tsobnang', 'F.', '', 'ISMANS'],
#   ['Bangoup', 'S.', '', 'ISMANS'],
#   ['Dzangue', 'F.', '', 'ISMANS'],
#   ['Jeatsa', 'A.', '', 'ISMANS'],
#   ['Méhauté', 'A. Le', '', 'ISMANS']],
#  '0704.0881': [['Lee', 'Jounghun', '', "Seoul Nat'l Univ."],
#   ['Park', 'Daeseong', '', "Seoul Nat'l Univ."]],
#  '0704.0882': [['Roos', 'Matts', '']],
#  '0704.0883': [['Hosotani', 'Yutaka', '']],
#  '0704.0884': [['Pflug', 'Peter', ''], ['Nguyen', 'Viet-Anh', '']],
#  '0704.0885': [['Pachl', 'Jan', '']],
#  '0704.0886': [['Jung', 'Peter', ''], ['Rosch', 'Achim', '']],
#  '0704.0887': [['Apostolov', 'S. S.', ''],
#   ['Mayzelis', 'Z. A.', ''],
#   ['Usatenko', 'O. V.', ''],
#   ["Yampol'skii", 'V. A.', '']],
#  '0704.0888': [['Kramer', 'S.', '', 'LCMI'],
#   ['Stern', 'R.', '', 'LCMI'],
#   ['Horvatic', 'M.', '', 'LCMI'],
#   ['Berthier', 'C.', '', 'LCMI'],
#   ['Kimura', 'T.', '', 'LANL'],
#   ['Fisher', 'I. R.', '']],
#  '0704.0889': [['van Raan', 'Anthony F. J.', '']],
#  '0704.0890': [['Orlando', 'S.', ''],
#   ['Bocchino', 'F.', ''],
#   ['Reale', 'F.', ''],
#   ['Peres', 'G.', ''],
#   ['Petruk', 'O.', '']],
#  '0704.0891': [['Cribier', 'M.', '', 'APC']],
#  '0704.0892': [['Wang', 'Xingang', ''],
#   ['Zhan', 'Meng', ''],
#   ['Guan', 'Ghuguang', ''],
#   ['Lai', 'Choy Heng', '']],
#  '0704.0893': [['Souza', 'C. E. R.', ''],
#   ['Huguenin', 'J. A. O.', ''],
#   ['Milman', 'P.', ''],
#   ['Khoury', 'A. Z.', '']],
#  '0704.0894': [['Subasavage', 'John P.', ''],
#   ['Henry', 'Todd J.', ''],
#   ['Bergeron', 'P.', ''],
#   ['Dufour', 'P.', ''],
#   ['Hambly', 'Nigel C.', ''],
#   ['Beaulieu', 'Thomas D.', '']],
#  '0704.0895': [['Perrin', 'Nicolas', '']],
#  '0704.0896': [['Dudka', 'M.', ''],
#   ['Folk', 'R.', ''],
#   ['Holovatch', 'Yu.', ''],
#   ['Moser', 'G.', '']],
#  '0704.0897': [['Nguyen', 'Viet-Anh', '']],
#  '0704.0898': [['Bekaert', 'Xavier', '']],
#  '0704.0899': [['Dixon', 'W. V.', '', '2 and 3'],
#   ['Sahnow', 'D. J.', '', '2 and 3'],
#   ['Barrett', 'P. E.', '', '2 and 3'],
#   ['Civeit', 'T.', '', '1 and 4'],
#   ['Dupuis', 'J.', '', '1 and 5'],
#   ['Fullerton', 'A. W.', '', '1 and 6'],
#   ['Godard', 'B.', '', '1 and\n  7'],
#   ['Hsu', 'J. C.', '', '2 and 8'],
#   ['Kaiser', 'M. E.', '', '1 and\n  9'],
#   ['Kruk', 'J. W.', '', '1 and\n  9'],
#   ['Lacour', 'S.', '', '1 and\n  9'],
#   ['Lindler', 'D. J.', '', '1 and 8'],
#   ['Massa', 'D.', '', '1 and 8'],
#   ['Robinson', 'R. D.', '', '1 and 8'],
#   ['Romelfanger', 'M. L.', ''],
#   ['Sonnentrucker', 'P.', '']],
#  '0704.0900': [['Doucot', 'Benoit', ''], ['Ioffe', 'Lev B.', '']],
#  '0704.0901': [['Simmons', 'Jacob J. H.', ''],
#   ['Kleban', 'Peter', ''],
#   ['Dahlberg', 'Kevin', ''],
#   ['Ziff', 'Robert M.', '']],
#  '0704.0902': [['Tomczak', 'Jan M.', ''],
#   ['Aryasetiawan', 'Ferdi', ''],
#   ['Biermann', 'Silke', '']],
#  '0704.0903': [['Conte', 'Elio', ''],
#   ['Khrennikov', 'Andrei Yu.', ''],
#   ['Zbilut', 'Joseph P.', '']],
#  '0704.0904': [['Corbet', 'Robin', ''], ['Dubois', 'Richard', '']],
#  '0704.0905': [['Lukić', 'D. V.', ''],
#   ['Schnell', 'M.', ''],
#   ['Savin', 'D. W.', ''],
#   ['Brandau', 'C.', ''],
#   ['Schmidt', 'E. W.', ''],
#   ['Böhm', 'S.', ''],
#   ['Müller', 'A.', ''],
#   ['Schippers', 'S.', ''],
#   ['Lestinsky', 'M.', ''],
#   ['Sprenger', 'F.', ''],
#   ['Wolf', 'A.', ''],
#   ['Altun', 'Z.', ''],
#   ['Badnell', 'N. R.', '']],
#  '0704.0906': [['Federico', 'Bassetti', ''], ['Fabrizio', 'Leisen', '']],
#  '0704.0907': [['Zakka-Bajjani', 'Eva', '', 'SPEC'],
#   ['Segala', 'Julien', '', 'SPEC'],
#   ['Portier', 'Fabien', '', 'SPEC'],
#   ['Roche', 'Patrice', '', 'SPEC'],
#   ['Glattli', 'Christian', '', 'SPEC'],
#   ['Cavanna', 'Antonella', '', 'LPN'],
#   ['Jin', 'Yong', '', 'LPN']],
#  '0704.0908': [['Rudnick', 'Lawrence', ''],
#   ['Brown', 'Shea', ''],
#   ['Williams', 'Liliya R.', '']],
#  '0704.0909': [['Azzali', 'Sara', '']],
#  '0704.0910': [['Park', 'Efton', ''], ['Trout', 'Jody', '']],
#  '0704.0911': [['Elmegreen', 'Debra Meloy', ''],
#   ['Elmegreen', 'Bruce G.', ''],
#   ['Ferguson', 'Thomas', ''],
#   ['Mullan', 'Brendan', '']],
#  '0704.0912': [['Boyd', 'Martin M.', ''],
#   ['Zelevinsky', 'Tanya', ''],
#   ['Ludlow', 'Andrew D.', ''],
#   ['Blatt', 'Sebastian', ''],
#   ['Zanon-Willette', 'Thomas', ''],
#   ['Foreman', 'Seth M.', ''],
#   ['Ye', 'Jun', '']],
#  '0704.0913': [['Lu', 'Zhihong', ''],
#   ['Visscher', 'P. B.', ''],
#   ['Butler', 'W. H.', '']],
#  '0704.0914': [['Greenleaf', 'Allan', ''],
#   ['Kurylev', 'Yaroslav', ''],
#   ['Lassas', 'Matti', ''],
#   ['Uhlmann', 'Gunther', '']],
#  '0704.0915': [['Noda', 'S.', ''],
#   ['Hasegawa', 'K.', ''],
#   ['Sugime', 'H.', ''],
#   ['Kakehi', 'K.', ''],
#   ['Zhang', 'Z.', ''],
#   ['Maruyama', 'S.', ''],
#   ['Yamaguchi', 'Y.', '']],
#  '0704.0916': [['Voinov', 'A. V.', ''],
#   ['Grimes', 'S. M.', ''],
#   ['Brune', 'C. R.', ''],
#   ['Hornish', 'M. J.', ''],
#   ['Massey', 'T. N.', ''],
#   ['Salas', 'A.', '']],
#  '0704.0917': [['Naef', 'Dominique', ''],
#   ['Mayor', 'Michel', ''],
#   ['Benz', 'Willy', ''],
#   ['Bouchy', 'Francois', ''],
#   ['Curto', 'Gaspare Lo', ''],
#   ['Lovis', 'Christophe', ''],
#   ['Moutou', 'Claire', ''],
#   ['Pepe', 'Francesco', ''],
#   ['Queloz', 'Didier', ''],
#   ['Santos', 'Nuno C.', ''],
#   ['Udry', 'Stephane', '']],
#  '0704.0918': [['Sullivant', 'Seth', '']],
#  '0704.0919': [['Zelyak', 'Oleksandr', ''],
#   ['Murthy', 'Ganpathy', ''],
#   ['Rozhkov', 'Igor', '']],
#  '0704.0920': [['Grigorenko', 'L. V.', ''], ['Zhukov', 'M. V.', '']],
#  '0704.0921': [['Balachandran', 'A. P.', ''], ['Jo', 'S. G.', '']],
#  '0704.0922': [['Pham', 'Quang-Cuong', '', 'LPPA, College de France']],
#  '0704.0923': [['Miller', 'Steven J.', '']],
#  '0704.0924': [['Miller', 'Steven J.', '']],
#  '0704.0925': [['Black', 'A. T.', ''],
#   ['Gomez', 'E.', ''],
#   ['Turner', 'L. D.', ''],
#   ['Jung', 'S.', ''],
#   ['Lett', 'P. D.', '']],
#  '0704.0926': [['Pham', 'Q. -C.', ''],
#   ['Tabareau', 'N.', ''],
#   ['Slotine', 'J. -J.', '']],
#  '0704.0927': [['Miller', 'Steven J.', '']],
#  '0704.0928': [['Anchordoqui', 'Luis', ''],
#   ['Goldberg', 'Haim', ''],
#   ['Nawata', 'Satoshi', ''],
#   ['Nunez', 'Carlos', '']],
#  '0704.0929': [['Yang', 'Hyun Seok', '']],
#  '0704.0930': [['Erler', 'Theodore', '']],
#  '0704.0931': [['Pasquali', 'Anna', '', 'MPIA'],
#   ['Bosch', 'Frank C. van den', '', 'MPIA'],
#   ['Rix', 'Hans-Walter', '', 'MPIA']],
#  '0704.0932': [['Kang', 'Xi', '', 'MPIA'],
#   ['Bosch', 'Frank C. van den', '', 'MPIA'],
#   ['Pasquali', 'Anna', '', 'MPIA']],
#  '0704.0933': [['Wang', 'Fa', ''],
#   ['Vishwanath', 'Ashvin', ''],
#   ['Kim', 'Yong Baek', '']],
#  '0704.0934': [['Grigorenko', 'L. V.', ''], ['Zhukov', 'M. V.', '']],
#  '0704.0935': [['Dementsov', 'Alexander', ''], ['Privman', 'Vladimir', '']],
#  '0704.0936': [['Okawa', 'Yuji', '', 'DESY']],
#  '0704.0937': [['Boyko', 'Vyacheslav', ''],
#   ['Patera', 'Jiri', ''],
#   ['Popovych', 'Roman', '']],
#  '0704.0938': [['Wang', 'Hui', ''],
#   ['Barros', 'Kipton', ''],
#   ['Gould', 'Harvey', ''],
#   ['Klein', 'W.', '']],
#  '0704.0939': [['Nandikotkur', 'Giridhar', ''],
#   ['Jahoda', 'Keith M.', ''],
#   ['Hartman', 'R. C.', ''],
#   ['Mukherjee', 'R.', ''],
#   ['Sreekumar', 'P.', ''],
#   ['Böttcher', 'M.', ''],
#   ['Sambruna', 'R. M.', ''],
#   ['Swank', 'Jean H.', '']],
#  '0704.0940': [['Orland', 'Peter', '']],
#  '0704.0941': [['Tojeiro', 'Rita', '', 'IfA, Edinburgh'],
#   ['Heavens', 'Alan F.', '', 'IfA, Edinburgh'],
#   ['Jimenez', 'Raul', '', 'UPenn'],
#   ['Panter', 'Ben', '', 'IfA, Edinburgh']],
#  '0704.0942': [['DeMarco', 'Laura', ''], ['Hruska', 'Suzanne Lynch', '']],
#  '0704.0943': [['LIGO Scientific Collaboration', '', '']],
#  '0704.0944': [['Kuhlen', 'Michael', ''],
#   ['Diemand', 'Jürg', ''],
#   ['Madau', 'Piero', '']],
#  '0704.0945': [['McCullagh', 'Peter', ''],
#   ['Pitman', 'Jim', ''],
#   ['Winkel', 'Matthias', '']],
#  '0704.0946': [['Mesinger', 'Andrei', ''], ['Furlanetto', 'Steven', '']],
#  '0704.0947': [['Matsushita', 'Satoki', '', 'ASIAA'],
#   ['Muller', 'Sebastien', '', 'ASIAA'],
#   ['Lim', 'Jeremy', '', 'ASIAA']],
#  '0704.0948': [['Sheets', 'H. A.', ''],
#   ['Thorstensen', 'J. R.', ''],
#   ['Peters', 'C. J.', ''],
#   ['Kapusta', 'A. B.', ''],
#   ['Taylor', 'C. J.', '']],
#  '0704.0949': [['Frederico', 'Gastao S. F.', ''],
#   ['Torres', 'Delfim F. M.', '']],
#  '0704.0950': [['Joshi', 'Yogesh C.', '', "Queen's University Belfast"]],
#  '0704.0951': [['Hoyos', 'J. A.', ''],
#   ['Vieira', 'André P.', ''],
#   ['Laflorencie', 'Nicolas', ''],
#   ['Miranda', 'E.', '']],
#  '0704.0952': [['Shao', 'M.', '', 'JPL'],
#   ['Marcy', 'G.', '', 'Univ. California'],
#   ['Unwin', 'S.', '', 'JPL'],
#   ['Allen', 'R.', '', 'STScI'],
#   ['Beichman', 'C.', '', 'MSC/Caltech'],
#   ['Catanzarite', 'J.', '', 'JPL'],
#   ['Chaboyer', 'B.', '', 'Dartmouth'],
#   ['Ciardi', 'D.', '', 'MSC/Caltech'],
#   ['Edberg', 'S. J.', '', 'JPL'],
#   ['Gallagher', 'D.', '', 'JPL'],
#   ['Gould', 'A.', '', 'Ohio State'],
#   ['Henry', 'T.', '', 'Georgia State'],
#   ['Johnston', 'K.', '', 'USNO'],
#   ['Kulkarni', 'S.', '', 'Caltech'],
#   ['Law', 'N.', '', 'Caltech'],
#   ['Majewski', 'S.', '', 'Univ. Virginia'],
#   ['Marr', 'J.', '', 'JPL'],
#   ['Law', 'N.', '', 'Caltech'],
#   ['Pan', 'X.', '', 'JPL'],
#   ['Shaklan', 'S.', '', 'JPL'],
#   ['Shaya', 'E.', '', 'Univ.\n  Maryland'],
#   ['Tanner', 'A.', '', 'JPL'],
#   ['Tomsick', 'J.', '', 'Univ. California'],
#   ['Wehrle', 'A.', '', 'Space\n  Sci Inst'],
#   ['Worthey', 'G.', '', 'Washington State Univ']],
#  '0704.0953': [['Bai', 'Lei', ''],
#   ['Marcillac', 'Delphine', ''],
#   ['Rieke', 'George H.', ''],
#   ['Rieke', 'Marcia J.', ''],
#   ['Tran', 'Kim-Vy H.', ''],
#   ['Hinz', 'Joannah L.', ''],
#   ['Rudnick', 'Gregory', ''],
#   ['Kelly', 'Douglas M.', ''],
#   ['Blaylock', 'Myra', '']],
#  '0704.0954': [['Kar', 'Soummya', ''], ['Moura', 'Jose M. F.', '']],
#  '0704.0955': [['Suryanarayana', 'Nemani V.', ''],
#   ['Wapler', 'Matthias C.', '']],
#  '0704.0956': [['Das', 'Tanmoy', ''],
#   ['Markiewicz', 'R. S.', ''],
#   ['Bansil', 'A.', '']],
#  '0704.0957': [['Pal', 'Soumik', ''], ['Pitman', 'Jim', '']],
#  '0704.0958': [['Pian', 'E.', ''],
#   ['Romano', 'P.', ''],
#   ['Treves', 'A.', ''],
#   ['Ghisellini', 'G.', ''],
#   ['Covino', 'S.', ''],
#   ['Cucchiara', 'A.', ''],
#   ['Dolcini', 'A.', ''],
#   ['Tagliaferri', 'G.', ''],
#   ['Markwardt', 'C.', ''],
#   ['Campana', 'S.', ''],
#   ['Chincarini', 'G.', ''],
#   ['Gehrels', 'N.', ''],
#   ['Giommi', 'P.', ''],
#   ['Maraschi', 'L.', ''],
#   ['Vergani', 'S. D.', ''],
#   ['Zerbi', 'F. M.', ''],
#   ['Molinari', 'E.', ''],
#   ['Testa', 'V.', ''],
#   ['Tosti', 'G.', ''],
#   ['Vitali', 'F.', ''],
#   ['Antonelli', 'L. A.', ''],
#   ['Conconi', 'P.', ''],
#   ['Malaspina', 'G.', ''],
#   ['Nicastro', 'L.', ''],
#   ['Palazzi', 'E.', ''],
#   ['Meurs', 'E. J. A.', ''],
#   ['Norci', 'L.', '']],
#  '0704.0959': [['Doi', 'Takumi', '', 'Kentucky U., Riken BNL']],
#  '0704.0960': [['Huo', 'Wen Yi', ''], ['Long', 'Gui Lu', '']],
#  '0704.0961': [['Tovmassian', 'G. H.', ''], ['Zharikov', 'S. V.', '']],
#  '0704.0962': [['Sauer', 'Tilman', '']],
#  '0704.0963': [['Sauer', 'Tilman', '']],
#  '0704.0964': [['Bravyi', 'Sergey', '']],
#  '0704.0965': [['Yu', 'Zongwen', ''], ['Hu', 'Su', '']],
#  '0704.0966': [['Alver', 'B.', ''], ['Collaboration', 'the PHOBOS', '']],
#  '0704.0967': [['Liu', 'Jia', ''], ['Hou', 'Y. Thomas', '']],
#  '0704.0968': [['Han', 'Cheongho', '', 'Chunguk Natl. Univ.']],
#  '0704.0969': [['Hu', 'Su', ''], ['Yu', 'Zongwen', '']],
#  '0704.0970': [['Wardle', 'Mark', '', 'Macquarie University']],
#  '0704.0971': [['Xing', 'Zhi-zhong', ''], ['Zhou', 'Shun', '']],
#  '0704.0972': [['Prigara', 'Fedor V.', '']],
#  '0704.0973': [['Lu', 'Fangjun', ''],
#   ['Wang', 'Q. Daniel', ''],
#   ['Gotthelf', 'E. V.', ''],
#   ['Qu', 'Jinlu', '']],
#  '0704.0974': [['Kawamura', 'Hikaru', ''], ['Yamamoto', 'Atsushi', '']],
#  '0704.0975': [['Sarkar', 'A.', ''],
#   ['Webber', 'Charles L.', 'Jr.'],
#   ['Barat', 'P.', ''],
#   ['Mukherjee', 'P.', '']],
#  '0704.0976': [['Eckmann', 'Jean-Pierre', '']],
#  '0704.0977': [['Yang', 'Wei', ''],
#   ['Wang', 'Ru-Zhi', ''],
#   ['Wang', 'Yu-Fang', ''],
#   ['Song', 'Xue-Mei', ''],
#   ['Wang', 'Bo', ''],
#   ['Yan', 'Hui', '']],
#  '0704.0978': [['Muller', 'S.', ''],
#   ['Guelin', 'M.', ''],
#   ['Combes', 'F.', ''],
#   ['Wiklind', 'T.', '']],
#  '0704.0979': [['Takami', 'Hajime', ''],
#   ['Murase', 'Kohta', ''],
#   ['Nagataki', 'Shigehiro', ''],
#   ['Sato', 'Katsuhiko', '']],
#  '0704.0980': [['Pfund', 'A.', ''],
#   ['Shorubalko', 'I.', ''],
#   ['Ensslin', 'K.', ''],
#   ['Leturcq', 'R.', '']],
#  '0704.0981': [['Nguyen', 'Xuan Hien', '']],
#  '0704.0982': [['Drobyshevski', 'Edward M.', ''],
#   ['Drobyshevski', 'Mikhail E.', '']],
#  '0704.0983': [['Gerasyuta', 'S. M.', ''], ['Durnev', 'M. A.', '']],
#  '0704.0984': [['Bose', 'Sougato', ''],
#   ['Angelakis', 'Dimitris G.', ''],
#   ['Burgarth', 'Daniel', '']],
#  '0704.0985': [['Abubakr', 'Mohd', ''], ['Vinay', 'R. M.', '']],
#  '0704.0986': [['Maluf', 'J. W.', ''],
#   ['Faria', 'F. F.', ''],
#   ['Ulhoa', 'S. C.', '']],
#  '0704.0987': [['Munoz', 'C.', '']],
#  '0704.0988': [['Cyganowski', 'C. J.', ''],
#   ['Brogan', 'C. L.', ''],
#   ['Hunter', 'T. R.', '']],
#  '0704.0989': [['Groves', 'Daniel', ''], ['Wilton', 'Henry', '']],
#  '0704.0990': [['Ruan', 'Chong-Yu', ''],
#   ['Murooka', 'Yoshie', ''],
#   ['Raman', 'Ramani K.', ''],
#   ['Murdick', 'Ryan A.', '']],
#  '0704.0991': [['Egami', 'Masahiko', '']],
#  '0704.0992': [['Magliaro', 'Elena', ''],
#   ['Perini', 'Claudio', ''],
#   ['Rovelli', 'Carlo', '']],
#  '0704.0993': [['Bizoń', 'Piotr', ''],
#   ['Chmaj', 'Tadeusz', ''],
#   ['Rostworowski', 'Andrzej', '']],
#  '0704.0994': [['Falmagne', 'J. -Cl.', ''], ['Ovchinnikov', 'S.', '']],
#  '0704.0995': [['Joglekar', 'Satish D.', '']],
#  '0704.0996': [['Sahay', 'Anurag', ''], ['Sengupta', 'Gautam', '']],
#  '0704.0997': [['Coman', 'Dan', ''], ['Poletsky', 'Evgeny A.', '']],
#  '0704.0998': [['Nyssen', 'Louise', '', 'I3M']],
#  '0704.0999': [['Lusztig', 'G.', '']],
#  '0704.1000': [['Zhang', 'L. M.', '']],
#  ...}

# %%
df_raw.loc[:, ['title', 'authors', 'abstract', 'comments']]
# Out:
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 1133984  Chaotic diffusion of complex trajectory and it...
# 1133985               A Decentralized IoT Data Marketplace
# 1133986  Theory of Single Photon Detection by a Photore...
# 1133987  CreativeBioMan: Brain and Body Wearable Comput...
# 1133988  Failure of scattering to solitary waves for lo...
#
#                                                    authors  \
# 0        C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                          Ileana Streinu and Louis Theran
# 2                                              Hongjun Pan
# 3                                             David Callan
# 4                 Wael Abu-Shammala and Alberto Torchinsky
# ...                                                    ...
# 1133984  Wen-Lei Zhao, Jiaozi Wang, Qian Wang, and Peiq...
# 1133985                    P. Gupta, S. Kanhere, R. Jurdak
# 1133986                    N. J. Harmon and M. E. Flatt\'e
# 1133987  Min Chen, Yingying Jiang, Yong Cao, Albert Y. ...
# 1133988                      Jason Murphy, Kenji Nakanishi
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 1133984    We investigate both the quantum and classica...
# 1133985    This paper proposes an architecture for dyna...
# 1133986    The long spin coherence times in ambient con...
# 1133987    Current artificial intelligence (AI) technol...
# 1133988    We consider nonlinear Schr\"odinger equation...
#
#                                         comments
# 0        37 pages, 15 figures; published version
# 1          To appear in Graphs and Combinatorics
# 2                            23 pages, 3 figures
# 3                                       11 pages
# 4                                           None
# ...                                          ...
# 1133984                      10 pages, 7 figures
# 1133985                       6 pages, 7 figures
# 1133986                                     None
# 1133987                                     None
# 1133988                                 12 pages
#
# [1133989 rows x 4 columns]

# %%
df_raw.to_parquet('data/papers.parquet')

# %% [markdown]
# ## Preprocess data

# %%
df_raw.sort_values('id')
# Out:
#                  id            submitter  \
# 0         0704.0001       Pavel Nadolsky
# 1         0704.0002         Louis Theran
# 2         0704.0003          Hongjun Pan
# 3         0704.0004         David Callan
# 4         0704.0005   Alberto Torchinsky
# ...             ...                  ...
# 1133984  1906.01798            Qian Wang
# 1133985  1906.01799          Pooja Gupta
# 1133986  1906.01800  Michael E. Flatt\'e
# 1133987  1906.01801       Yingying Jiang
# 1133988  1906.01802         Jason Murphy
#
#                                                    authors  \
# 0        C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                          Ileana Streinu and Louis Theran
# 2                                              Hongjun Pan
# 3                                             David Callan
# 4                 Wael Abu-Shammala and Alberto Torchinsky
# ...                                                    ...
# 1133984  Wen-Lei Zhao, Jiaozi Wang, Qian Wang, and Peiq...
# 1133985                    P. Gupta, S. Kanhere, R. Jurdak
# 1133986                    N. J. Harmon and M. E. Flatt\'e
# 1133987  Min Chen, Yingying Jiang, Yong Cao, Albert Y. ...
# 1133988                      Jason Murphy, Kenji Nakanishi
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 1133984  Chaotic diffusion of complex trajectory and it...
# 1133985               A Decentralized IoT Data Marketplace
# 1133986  Theory of Single Photon Detection by a Photore...
# 1133987  CreativeBioMan: Brain and Body Wearable Comput...
# 1133988  Failure of scattering to solitary waves for lo...
#
#                                         comments  \
# 0        37 pages, 15 figures; published version
# 1          To appear in Graphs and Combinatorics
# 2                            23 pages, 3 figures
# 3                                       11 pages
# 4                                           None
# ...                                          ...
# 1133984                      10 pages, 7 figures
# 1133985                       6 pages, 7 figures
# 1133986                                     None
# 1133987                                     None
# 1133988                                 12 pages
#
#                                        journal-ref  \
# 0                         Phys.Rev.D76:013009,2007
# 1                                             None
# 2                                             None
# 3                                             None
# 4        Illinois J. Math. 52 (2008) no.2, 681-689
# ...                                            ...
# 1133984                                       None
# 1133985                                       None
# 1133986                                       None
# 1133987                                       None
# 1133988                                       None
#
#                                 doi  \
# 0        10.1103/PhysRevD.76.013009
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 1133984                        None
# 1133985                        None
# 1133986                        None
# 1133987                        None
# 1133988                        None
#
#                                                   abstract         report-no  \
# 0          A fully differential calculation in perturba...  ANL-HEP-PR-07-12
# 1          We describe a new algorithm, the $(k,\ell)$-...              None
# 2          The evolution of Earth-Moon system is descri...              None
# 3          We show that a determinant of Stirling cycle...              None
# 4          In this paper we show how to compute the $\L...              None
# ...                                                    ...               ...
# 1133984    We investigate both the quantum and classica...              None
# 1133985    This paper proposes an architecture for dyna...              None
# 1133986    The long spin coherence times in ambient con...              None
# 1133987    Current artificial intelligence (AI) technol...              None
# 1133988    We consider nonlinear Schr\"odinger equation...              None
#
#                            categories      versions
# 0                            [hep-ph]      [v1, v2]
# 1                     [math.CO cs.CG]      [v1, v2]
# 2                    [physics.gen-ph]  [v1, v2, v3]
# 3                           [math.CO]          [v1]
# 4                   [math.CA math.FA]          [v1]
# ...                               ...           ...
# 1133984                    [quant-ph]  [v1, v2, v3]
# 1133985                       [cs.NI]          [v1]
# 1133986  [quant-ph cond-mat.mes-hall]          [v1]
# 1133987                       [cs.HC]          [v1]
# 1133988                     [math.AP]          [v1]
#
# [1133989 rows x 11 columns]

# %%
s_authors = pd.Series(authors_parsed).rename('authors')

# %%
s_authors.sort_index()
# Out:
# 0704.0001     [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 0704.0002              [[Streinu, Ileana, ], [Theran, Louis, ]]
# 0704.0003                                    [[Pan, Hongjun, ]]
# 0704.0004                                   [[Callan, David, ]]
# 0704.0005     [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
#                                     ...
# 1906.01798    [[Zhao, Wen-Lei, ], [Wang, Jiaozi, ], [Wang, Q...
# 1906.01799     [[Gupta, P., ], [Kanhere, S., ], [Jurdak, R., ]]
# 1906.01800               [[Harmon, N. J., ], [Flatté, M. E., ]]
# 1906.01801    [[Chen, Min, ], [Jiang, Yingying, ], [Cao, Yon...
# 1906.01802            [[Murphy, Jason, ], [Nakanishi, Kenji, ]]
# Name: authors, Length: 1133989, dtype: object

# %%
(s_authors.index.values == df_raw.loc[:, 'id'].values).all()
# Out:
# True

# %%
df_raw.drop(columns='authors')
# Out:
#                  id            submitter  \
# 0         0704.0001       Pavel Nadolsky
# 1         0704.0002         Louis Theran
# 2         0704.0003          Hongjun Pan
# 3         0704.0004         David Callan
# 4         0704.0005   Alberto Torchinsky
# ...             ...                  ...
# 1133984  1906.01798            Qian Wang
# 1133985  1906.01799          Pooja Gupta
# 1133986  1906.01800  Michael E. Flatt\'e
# 1133987  1906.01801       Yingying Jiang
# 1133988  1906.01802         Jason Murphy
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 1133984  Chaotic diffusion of complex trajectory and it...
# 1133985               A Decentralized IoT Data Marketplace
# 1133986  Theory of Single Photon Detection by a Photore...
# 1133987  CreativeBioMan: Brain and Body Wearable Comput...
# 1133988  Failure of scattering to solitary waves for lo...
#
#                                         comments  \
# 0        37 pages, 15 figures; published version
# 1          To appear in Graphs and Combinatorics
# 2                            23 pages, 3 figures
# 3                                       11 pages
# 4                                           None
# ...                                          ...
# 1133984                      10 pages, 7 figures
# 1133985                       6 pages, 7 figures
# 1133986                                     None
# 1133987                                     None
# 1133988                                 12 pages
#
#                                        journal-ref  \
# 0                         Phys.Rev.D76:013009,2007
# 1                                             None
# 2                                             None
# 3                                             None
# 4        Illinois J. Math. 52 (2008) no.2, 681-689
# ...                                            ...
# 1133984                                       None
# 1133985                                       None
# 1133986                                       None
# 1133987                                       None
# 1133988                                       None
#
#                                 doi  \
# 0        10.1103/PhysRevD.76.013009
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 1133984                        None
# 1133985                        None
# 1133986                        None
# 1133987                        None
# 1133988                        None
#
#                                                   abstract         report-no  \
# 0          A fully differential calculation in perturba...  ANL-HEP-PR-07-12
# 1          We describe a new algorithm, the $(k,\ell)$-...              None
# 2          The evolution of Earth-Moon system is descri...              None
# 3          We show that a determinant of Stirling cycle...              None
# 4          In this paper we show how to compute the $\L...              None
# ...                                                    ...               ...
# 1133984    We investigate both the quantum and classica...              None
# 1133985    This paper proposes an architecture for dyna...              None
# 1133986    The long spin coherence times in ambient con...              None
# 1133987    Current artificial intelligence (AI) technol...              None
# 1133988    We consider nonlinear Schr\"odinger equation...              None
#
#                            categories      versions
# 0                            [hep-ph]      [v1, v2]
# 1                     [math.CO cs.CG]      [v1, v2]
# 2                    [physics.gen-ph]  [v1, v2, v3]
# 3                           [math.CO]          [v1]
# 4                   [math.CA math.FA]          [v1]
# ...                               ...           ...
# 1133984                    [quant-ph]  [v1, v2, v3]
# 1133985                       [cs.NI]          [v1]
# 1133986  [quant-ph cond-mat.mes-hall]          [v1]
# 1133987                       [cs.HC]          [v1]
# 1133988                     [math.AP]          [v1]
#
# [1133989 rows x 10 columns]

# %%
df = pd.concat([df_raw.drop(columns='authors').set_index('id'), s_authors], axis=1)

# %%
df.head(3)
# Out:
#                 submitter                                              title  \
# id
# 0704.0001  Pavel Nadolsky  Calculation of prompt diphoton production cros...
# 0704.0002    Louis Theran           Sparsity-certifying Graph Decompositions
# 0704.0003     Hongjun Pan  The evolution of the Earth-Moon system based o...
#
#                                           comments               journal-ref  \
# id
# 0704.0001  37 pages, 15 figures; published version  Phys.Rev.D76:013009,2007
# 0704.0002    To appear in Graphs and Combinatorics                      None
# 0704.0003                      23 pages, 3 figures                      None
#
#                                   doi  \
# id
# 0704.0001  10.1103/PhysRevD.76.013009
# 0704.0002                        None
# 0704.0003                        None
#
#                                                     abstract  \
# id
# 0704.0001    A fully differential calculation in perturba...
# 0704.0002    We describe a new algorithm, the $(k,\ell)$-...
# 0704.0003    The evolution of Earth-Moon system is descri...
#
#                   report-no        categories      versions  \
# id
# 0704.0001  ANL-HEP-PR-07-12          [hep-ph]      [v1, v2]
# 0704.0002              None   [math.CO cs.CG]      [v1, v2]
# 0704.0003              None  [physics.gen-ph]  [v1, v2, v3]
#
#                                                      authors
# id
# 0704.0001  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 0704.0002           [[Streinu, Ileana, ], [Theran, Louis, ]]
# 0704.0003                                 [[Pan, Hongjun, ]]

# %% [markdown]
# See a sample of what the 'comments' column contains

# %%
for i, comment in enumerate(df.loc[:, 'comments'].head(50)):
    print('{}: {}'.format(i, comment))
# Out:
# 0: 37 pages, 15 figures; published version
# 1: To appear in Graphs and Combinatorics
# 2: 23 pages, 3 figures
# 3: 11 pages
# 4: None
# 5: 6 pages, 4 figures, accepted by PRA
# 6: 16 pages, no figures. Typos corrected to match published version
# 7: Minor corrections
# 8: None
# 9: 36 pages, 17 figures
# 10: 14 pages; title changed; to appear in Experimental Mathematics
# 11: None
# 12: None
# 13: 18 pages, 1 figure
# 14: 22 pages; signs and coefficients adjusted for anticommuting
#   superfields, section 4.3 changed accordingly, reference added
# 15: 17 pages, 3 figures and 1 table
# 16: 10 pages, 11 figures (figures 3, 4, 7 and 8 at reduced resolution,
#   originals available on request). Accepted for publication in Monthly Notices
#   of the Royal Astronomical Society
# 17: 20 pages, v2: an overall sign and typos corrected
# 18: 6 pages, Journal-ref added
# 19: 21 pages, 13 postscript figures, submitted to Phys. Rev. D,
#   contributed to 42nd Rencontres de Moriond: QCD and Hadronic Interactions
# 20: 5 pages, 4 figures
# 21: 20 pages, 4 figures
# 22: 4 pages, 2 figures, to appear in the proceedings of the conference
#   Science with ALMA: a new era for Astrophysics, Spain, 2006
# 23: First appeared in Prof. B. Hillebrands' research group Annual Report
#   2005 (http://www.physik.uni-kl.de/w_hilleb/ann05.html); also presented at
#   Intermag'2006 Conference: M. Kostylev, A.A. Serga, and B. Hillebrands,
#   Digests of International Magnetic Conference, May 8-12, 2006, San Diego, USA,
#   FV03 (2006)
# 24: 41 pages, 13 figures, in "Polarons in Advanced Materials" ed. A. S.
#   Alexandrov (Canopus/Springer Publishing, Bristol (2007)), pp. 503-544.
# 25: 31 pp. Second of 3-part "theorem/proof" exposition of 78-slide
#   Powerpoint from Wolfram Science's NKS 2006, available at
#   http://wolframscience.com/conference/2006/presentations/materials/demarrais.ppt
#   [v2: small fixes][v3: Added new Appendix B and small number of corrections
#   (pp. 7, 14, 20) RE: 2nd type of box-kite flow pattern.]
# 26: 4 pages, 2 figures; mistakes due to an erroneous electron-phonon
#   coupling constant have been corrected; mode splitting is larger than
#   originally expected
# 27: 10 pages
# 28: None
# 29: Reprint to improve access. 13 pages, 6 figures.
# 30: 11 pages, 3 figures
# 31: 21 pages, 12 figures, 17 postscript files
# 32: 23 pages, 5 figures
# 33: 5 pages
# 34: 17 pages, 8 figures
# 35: Resubmit with new results on the upper bound of the number of steady
#   states. 20 pages, 2 figures, See
#   http://www.math.rutgers.edu/~sontag/PUBDIR/index.html for online preprints
#   and reprints of related work
# 36: 13 pages, 10 figures
# 37: 36 pages, 1 figure
# 38: 18 pages, 3 figures. Some rewriting in the presentation of the
#   results and comments to previous works
# 39: Final version, published
# 40: improvements: (i) more general approach through quantum families of
#   isometries, following Woronowicz and Soltan's ideas; (ii) construction of
#   equivaraint spectral triples. also some minor changes. Improved and enlarged
#   version of ICTP preprint IC/2007/017
# 41: 12 pages,3 figures
# 42: 30 pages, 9 figures, 1 table
# 43: aastex using emulateapj, 65 pages, 10 figures; replaced to match
#   published version
# 44: accepted for publication in J. Fluid Mech.
# 45: LATEX file, 11 pages
# 46: 5 pages, 5 eps figures, uses IEEEtran.cls
# 47: GWDAW-11 proceeding, submitted to CQG, 10 pages, 3 figures, 1 table;
#   revised values in table
# 48: 17 pages.
# 49: 5 pages, 7 eps figures, uses IEEEtran.cls

# %% [markdown]
# See a sample of what the 'journal-ref' column contains

# %%
for i, data in enumerate(df.loc[:, 'journal-ref'].head(50)):
    print('{}: {}'.format(i, data))
# Out:
# 0: Phys.Rev.D76:013009,2007
# 1: None
# 2: None
# 3: None
# 4: Illinois J. Math. 52 (2008) no.2, 681-689
# 5: None
# 6: Phys.Rev.D76:044016,2007
# 7: Journal of Applied Physics, vol 104, 073536 (2008)
# 8: Astrophys.J.663:1149-1173,2007
# 9: None
# 10: None
# 11: None
# 12: None
# 13: None
# 14: JHEP 0705:034,2007
# 15: Commun.Theor.Phys.49:993-1000,2008
# 16: Mon.Not.Roy.Astron.Soc.378:211-220,2007
# 17: None
# 18: RIMS Kokyuroku, No.1551, pp.57-62 (2007)
# 19: Phys.Rev.D76:052005,2007
# 20: Phys. Rev. Lett. 99, 048301 (2007)
# 21: None
# 22: Astrophys.Space Sci.313:197-200,2008
# 23: None
# 24: None
# 25: None
# 26: Phys. Rev. Lett. 99, 087402 (2007)
# 27: Math. Res. Lett. 15 (2008), no. 2, 351--358
# 28: Phys.Rev.D75:094018,2007
# 29: J. Low. Temp. Phys. Vol. 140 pp77-89 (2005)
# 30: Phys.Lett.B658:7-12,2007
# 31: Phys.Rev.D76:053001,2007
# 32: J.Opt.Soc.Am.A 23(10): 2578-2591 (2006)
# 33: None
# 34: J.Opt.Soc.Am.A 23(10): 2592-2601 (2006)
# 35: None
# 36: J.Quant.Spectrosc.Radiat.Transf. 106, 546-557 (2007)
# 37: J.Quant.Spectrosc.Radiat.Transf. 106, 558-589 (2007)
# 38: Phys.Lett.B651:139-146,2007
# 39: None
# 40: None
# 41: None
# 42: Physica A, V. 387, Issues 2-3 (2008), Pages 385-406
# 43: ApJS 182, 310 (2009)
# 44: J. Fluid Mech. 585, 213-244 (2007)
# 45: J. Math. Phys. 48(2007), 092102.
# 46: None
# 47: Class.Quant.Grav.24:S541-S550,2007
# 48: None
# 49: None

# %% [markdown]
# ### Explore ambiguous columns

# %% [markdown]
# #### journal-ref

# %% [markdown]
# Explore number of null vs non-null values

# %%
# Null values
df.loc[:, 'journal-ref'].isna().sum()
# Out:
# 721031

# %%
# Non-null values
(~df.loc[:, 'journal-ref'].isna()).sum()
# Out:
# 412958

# %%
df.loc[:, 'journal-ref'].value_counts().head(10)
# Out:
# Dans Design, Automation and Test in Europe - DATE'05, Munich :\n  Allemagne (2005)                                                        128
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2008, Nice : France (2008)                               77
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2007, Stresa, lago Maggiore : Italie (2007)              66
# Prog Theor Exp Phys (2018)                                                                                                                 57
# Prog Theor Exp Phys (2017)                                                                                                                 53
# Prog Theor Exp Phys (2019)                                                                                                                 52
# Dans Symposium on Design, Test, Integration and Packaging of\n  MEMS/MOEMS - DTIP 2006, Stresa, Lago Maggiore : Italie (2006)              49
# Dans Design, Automation and Test in Europe | Designers'Forum -\n  DATE'05, Munich : Allemagne (2005)                                       41
# Dans Proceedings of the 25th Annual Symposium on the Theoretical\n  Aspects of Computer Science - STACS 2008, Bordeaux : France (2008)     39
# Dans Proceedings of 12th International Workshop on Thermal\n  investigations of ICs - THERMINIC 2006, Nice : France (2006)                 37
# Name: journal-ref, dtype: int64

# %% [markdown]
# Do the same fo report-no

# %% [markdown]
# #### report-no

# %% [markdown]
# Explore number of null vs non-null values

# %%
# Null values
df.loc[:, 'report-no'].isna().sum()
# Out:
# 1067617

# %%
# Non-null values
(~df.loc[:, 'report-no'].isna()).sum()
# Out:
# 66372

# %%
df.loc[:, 'report-no'].value_counts()
# Out:
# CPH-SYM-DNRF92                              317
# CPH-SYM-00                                  138
# Roma01.Math                                 134
# ISSN 1947 5500                              131
# Mittag-Leffler-2011spring                    58
#                                            ...
# LHCb-PAPER-2012-024; CERN-PH-EP-2012-263      1
# CERN-LHCC-2018-027 LHCB-PUB-2018-009          1
# IMS-AOAS-AOAS466                              1
# DESY 15-124                                   1
# Argonne report ANL-HEP-CP-09-92               1
# Name: report-no, Length: 64476, dtype: int64

# %% [markdown]
# #### comments

# %%
# Null values
df.loc[:, 'comments'].isna().sum()
# Out:
# 262263

# %%
# Non-null values
(~df.loc[:, 'comments'].isna()).sum()
# Out:
# 871726

# %% [markdown]
# Conclusion: journal-ref and commentts are potentially useful, but an overwhelming number of report-no values are null and can thus be excluded

# %% [markdown]
# #### Extract the useful columns only

# %%
df.columns
# Out:
# Index(['submitter', 'title', 'comments', 'journal-ref', 'doi', 'abstract',
#        'report-no', 'categories', 'versions', 'authors'],
#       dtype='object')

# %%
columns = ['title', 'authors', 'submitter', 'abstract', 'categories', 'journal-ref', 'comments']

# %%
papers = df.loc[:, columns]

# %%
papers.head()
# Out:
#                                                        title  \
# id
# 0704.0001  Calculation of prompt diphoton production cros...
# 0704.0002           Sparsity-certifying Graph Decompositions
# 0704.0003  The evolution of the Earth-Moon system based o...
# 0704.0004  A determinant of Stirling cycle numbers counts...
# 0704.0005  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                                      authors  \
# id
# 0704.0001  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 0704.0002           [[Streinu, Ileana, ], [Theran, Louis, ]]
# 0704.0003                                 [[Pan, Hongjun, ]]
# 0704.0004                                [[Callan, David, ]]
# 0704.0005  [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
#
#                     submitter  \
# id
# 0704.0001      Pavel Nadolsky
# 0704.0002        Louis Theran
# 0704.0003         Hongjun Pan
# 0704.0004        David Callan
# 0704.0005  Alberto Torchinsky
#
#                                                     abstract  \
# id
# 0704.0001    A fully differential calculation in perturba...
# 0704.0002    We describe a new algorithm, the $(k,\ell)$-...
# 0704.0003    The evolution of Earth-Moon system is descri...
# 0704.0004    We show that a determinant of Stirling cycle...
# 0704.0005    In this paper we show how to compute the $\L...
#
#                   categories                                journal-ref  \
# id
# 0704.0001           [hep-ph]                   Phys.Rev.D76:013009,2007
# 0704.0002    [math.CO cs.CG]                                       None
# 0704.0003   [physics.gen-ph]                                       None
# 0704.0004          [math.CO]                                       None
# 0704.0005  [math.CA math.FA]  Illinois J. Math. 52 (2008) no.2, 681-689
#
#                                           comments
# id
# 0704.0001  37 pages, 15 figures; published version
# 0704.0002    To appear in Graphs and Combinatorics
# 0704.0003                      23 pages, 3 figures
# 0704.0004                                 11 pages
# 0704.0005                                     None

# %% [markdown]
# ## Manipulate categories to make the information more useful

# %%
papers.iloc[1]['categories']
# Out:
# ['math.CO cs.CG']

# %%
import typing

# %% [markdown]
# Define a function to process the categories columns and convert them from a list of a single string to a list/set of distinct strings

# %%
def process_categories(cat: typing.List[str]) -> typing.List[str]:
    s = cat[0]
    cat_list = s.split()
    return set(sorted(cat_list))

# %%
all_categories = set()
for c in papers.loc[:, 'categories']:
    all_categories |= process_categories(c)

# %%
all_categories
# Out:
# {'astro-ph',
#  'astro-ph.CO',
#  'astro-ph.EP',
#  'astro-ph.GA',
#  'astro-ph.HE',
#  'astro-ph.IM',
#  'astro-ph.SR',
#  'cond-mat.dis-nn',
#  'cond-mat.mes-hall',
#  'cond-mat.mtrl-sci',
#  'cond-mat.other',
#  'cond-mat.quant-gas',
#  'cond-mat.soft',
#  'cond-mat.stat-mech',
#  'cond-mat.str-el',
#  'cond-mat.supr-con',
#  'cs.AI',
#  'cs.AR',
#  'cs.CC',
#  'cs.CE',
#  'cs.CG',
#  'cs.CL',
#  'cs.CR',
#  'cs.CV',
#  'cs.CY',
#  'cs.DB',
#  'cs.DC',
#  'cs.DL',
#  'cs.DM',
#  'cs.DS',
#  'cs.ET',
#  'cs.FL',
#  'cs.GL',
#  'cs.GR',
#  'cs.GT',
#  'cs.HC',
#  'cs.IR',
#  'cs.IT',
#  'cs.LG',
#  'cs.LO',
#  'cs.MA',
#  'cs.MM',
#  'cs.MS',
#  'cs.NA',
#  'cs.NE',
#  'cs.NI',
#  'cs.OH',
#  'cs.OS',
#  'cs.PF',
#  'cs.PL',
#  'cs.RO',
#  'cs.SC',
#  'cs.SD',
#  'cs.SE',
#  'cs.SI',
#  'cs.SY',
#  'econ.EM',
#  'econ.GN',
#  'econ.TH',
#  'eess.AS',
#  'eess.IV',
#  'eess.SP',
#  'eess.SY',
#  'gr-qc',
#  'hep-ex',
#  'hep-lat',
#  'hep-ph',
#  'hep-th',
#  'math-ph',
#  'math.AC',
#  'math.AG',
#  'math.AP',
#  'math.AT',
#  'math.CA',
#  'math.CO',
#  'math.CT',
#  'math.CV',
#  'math.DG',
#  'math.DS',
#  'math.FA',
#  'math.GM',
#  'math.GN',
#  'math.GR',
#  'math.GT',
#  'math.HO',
#  'math.IT',
#  'math.KT',
#  'math.LO',
#  'math.MG',
#  'math.MP',
#  'math.NA',
#  'math.NT',
#  'math.OA',
#  'math.OC',
#  'math.PR',
#  'math.QA',
#  'math.RA',
#  'math.RT',
#  'math.SG',
#  'math.SP',
#  'math.ST',
#  'nlin.AO',
#  'nlin.CD',
#  'nlin.CG',
#  'nlin.PS',
#  'nlin.SI',
#  'nucl-ex',
#  'nucl-th',
#  'physics.acc-ph',
#  'physics.ao-ph',
#  'physics.app-ph',
#  'physics.atm-clus',
#  'physics.atom-ph',
#  'physics.bio-ph',
#  'physics.chem-ph',
#  'physics.class-ph',
#  'physics.comp-ph',
#  'physics.data-an',
#  'physics.ed-ph',
#  'physics.flu-dyn',
#  'physics.gen-ph',
#  'physics.geo-ph',
#  'physics.hist-ph',
#  'physics.ins-det',
#  'physics.med-ph',
#  'physics.optics',
#  'physics.plasm-ph',
#  'physics.pop-ph',
#  'physics.soc-ph',
#  'physics.space-ph',
#  'q-bio.BM',
#  'q-bio.CB',
#  'q-bio.GN',
#  'q-bio.MN',
#  'q-bio.NC',
#  'q-bio.OT',
#  'q-bio.PE',
#  'q-bio.QM',
#  'q-bio.SC',
#  'q-bio.TO',
#  'q-fin.CP',
#  'q-fin.EC',
#  'q-fin.GN',
#  'q-fin.MF',
#  'q-fin.PM',
#  'q-fin.PR',
#  'q-fin.RM',
#  'q-fin.ST',
#  'q-fin.TR',
#  'quant-ph',
#  'stat.AP',
#  'stat.CO',
#  'stat.ME',
#  'stat.ML',
#  'stat.OT',
#  'stat.TH'}

# %% [markdown]
# ### processed_categories

# %% [markdown]
# Create a column 'processed_categories' with the categories now listed as separate strings

# %%
papers['processed_categories'] = papers['categories'].apply(process_categories)

# %%
papers.head()
# Out:
#                                                        title  \
# id
# 0704.0001  Calculation of prompt diphoton production cros...
# 0704.0002           Sparsity-certifying Graph Decompositions
# 0704.0003  The evolution of the Earth-Moon system based o...
# 0704.0004  A determinant of Stirling cycle numbers counts...
# 0704.0005  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                                      authors  \
# id
# 0704.0001  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 0704.0002           [[Streinu, Ileana, ], [Theran, Louis, ]]
# 0704.0003                                 [[Pan, Hongjun, ]]
# 0704.0004                                [[Callan, David, ]]
# 0704.0005  [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
#
#                     submitter  \
# id
# 0704.0001      Pavel Nadolsky
# 0704.0002        Louis Theran
# 0704.0003         Hongjun Pan
# 0704.0004        David Callan
# 0704.0005  Alberto Torchinsky
#
#                                                     abstract  \
# id
# 0704.0001    A fully differential calculation in perturba...
# 0704.0002    We describe a new algorithm, the $(k,\ell)$-...
# 0704.0003    The evolution of Earth-Moon system is descri...
# 0704.0004    We show that a determinant of Stirling cycle...
# 0704.0005    In this paper we show how to compute the $\L...
#
#                   categories                                journal-ref  \
# id
# 0704.0001           [hep-ph]                   Phys.Rev.D76:013009,2007
# 0704.0002    [math.CO cs.CG]                                       None
# 0704.0003   [physics.gen-ph]                                       None
# 0704.0004          [math.CO]                                       None
# 0704.0005  [math.CA math.FA]  Illinois J. Math. 52 (2008) no.2, 681-689
#
#                                           comments processed_categories
# id
# 0704.0001  37 pages, 15 figures; published version             {hep-ph}
# 0704.0002    To appear in Graphs and Combinatorics     {cs.CG, math.CO}
# 0704.0003                      23 pages, 3 figures     {physics.gen-ph}
# 0704.0004                                 11 pages            {math.CO}
# 0704.0005                                     None   {math.FA, math.CA}

# %%
num_of_categories = papers.loc[:, 'processed_categories'].apply(len)

# %%
(num_of_categories > 1).sum()
# Out:
# 498186

# %% [markdown]
# To make the categories more useful, generalize them into their prefixes (i.e. math, physics, cs, etc.)

# %%
def generalize_categories(cat: typing.Set[str]) -> typing.Union[typing.List[str], str]:
    gen_cats = []
    for c in cat:
        ss = c.split('.')
        prefix = ss[0]
        gen_cats.append(prefix)
    
    if len(set(gen_cats)) == 1:
        categories = gen_cats[0]
    else:
        categories = ', '.join(sorted(set(gen_cats)))
    
    return categories

# %%
papers['general_categories'] = papers.loc[:, 'processed_categories'].apply(generalize_categories)

# %%
papers.head(3)
# Out:
#                                                        title  \
# id
# 0704.0001  Calculation of prompt diphoton production cros...
# 0704.0002           Sparsity-certifying Graph Decompositions
# 0704.0003  The evolution of the Earth-Moon system based o...
#
#                                                      authors       submitter  \
# id
# 0704.0001  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...  Pavel Nadolsky
# 0704.0002           [[Streinu, Ileana, ], [Theran, Louis, ]]    Louis Theran
# 0704.0003                                 [[Pan, Hongjun, ]]     Hongjun Pan
#
#                                                     abstract  \
# id
# 0704.0001    A fully differential calculation in perturba...
# 0704.0002    We describe a new algorithm, the $(k,\ell)$-...
# 0704.0003    The evolution of Earth-Moon system is descri...
#
#                  categories               journal-ref  \
# id
# 0704.0001          [hep-ph]  Phys.Rev.D76:013009,2007
# 0704.0002   [math.CO cs.CG]                      None
# 0704.0003  [physics.gen-ph]                      None
#
#                                           comments processed_categories  \
# id
# 0704.0001  37 pages, 15 figures; published version             {hep-ph}
# 0704.0002    To appear in Graphs and Combinatorics     {cs.CG, math.CO}
# 0704.0003                      23 pages, 3 figures     {physics.gen-ph}
#
#           general_categories
# id
# 0704.0001             hep-ph
# 0704.0002           cs, math
# 0704.0003            physics

# %% [markdown]
# Check how many papers have more than one category

# %%
papers.loc[:, 'general_categories'].value_counts()
# Out:
# math                                   232992
# astro-ph                               131434
# cond-mat                               126090
# cs                                     124306
# physics                                 59257
#                                         ...
# math, math-ph, nlin, physics, stat          1
# math, math-ph, nlin, physics, q-bio         1
# hep-th, math, physics, q-bio, stat          1
# gr-qc, hep-ph, nucl-th, quant-ph            1
# cond-mat, cs, q-bio, quant-ph, stat         1
# Name: general_categories, Length: 1357, dtype: int64

# %%
all_general_categories = set()
for c in papers.loc[:, 'general_categories']:
    all_general_categories |= (c if type(c) == set else {c})

# %%
len(all_general_categories)
# Out:
# 1357

# %% [markdown]
# Get the number of category groupings with multiple categories

# %%
len([x for x in all_general_categories if ',' in x])
# Out:
# 1338

# %% [markdown]
# Get the list of single categories

# %%
sorted([x for x in all_general_categories if ',' not in x])
# Out:
# ['astro-ph',
#  'cond-mat',
#  'cs',
#  'econ',
#  'eess',
#  'gr-qc',
#  'hep-ex',
#  'hep-lat',
#  'hep-ph',
#  'hep-th',
#  'math',
#  'nlin',
#  'nucl-ex',
#  'nucl-th',
#  'physics',
#  'q-bio',
#  'q-fin',
#  'quant-ph',
#  'stat']

# %%
# Save useful information from model

# %% [markdown]
# ## Start using scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# %%
tfidf = tfidf_vectorizer.fit_transform(papers.loc[:, 'abstract'])

# %%
vectorize_text = (papers.loc[:, 'title'] + ' ') * 3 + papers.loc[:, 'abstract']

# %%
vectorize_text.iloc[0]
# Out:
# 'Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies   A fully differential calculation in perturbative quantum chromodynamics is\npresented for the production of massive photon pairs at hadron colliders. All\nnext-to-leading order perturbative contributions from quark-antiquark,\ngluon-(anti)quark, and gluon-gluon subprocesses are included, as well as\nall-orders resummation of initial-state gluon radiation valid at\nnext-to-next-to-leading logarithmic accuracy. The region of phase space is\nspecified in which the calculation is most reliable. Good agreement is\ndemonstrated with data from the Fermilab Tevatron, and predictions are made for\nmore detailed tests with CDF and DO data. Predictions are shown for\ndistributions of diphoton pairs produced at the energy of the Large Hadron\nCollider (LHC). Distributions of the diphoton pairs from the decay of a Higgs\nboson are contrasted with those produced from QCD processes at the LHC, showing\nthat enhanced sensitivity to the signal can be obtained with judicious\nselection of events.\n'

# %%
tfidf_wt = tfidf_vectorizer.fit_transform(vectorize_text)

# %%
kmeans_250 = MiniBatchKMeans(250)

# %%
model_250 = kmeans.fit(tfidf)

# %% [markdown]
# ### Play around with some examples

# %%
abs_1 = """
In this paper, we draw on control theory to understand the conditions under which the use of agile practices is most 
effective in improving software project quality. Although agile development methodologies offer the potential of 
improving software development outcomes, limited research has examined how project managers can structure the 
software development environment to maximize the benefits of agile methodology use during a project. As a result, 
project managers have little guidance on how to manage teams who are using agile methodologies. Arguing that the most 
effective control modes are those that provide teams with autonomy in determining the methods for achieving project 
objectives, we propose hypotheses related to the interaction between control modes, agile methodology use, and 
requirements change. We test the model in a field study of 862 software developers in 110 teams. The model explains 
substantial variance in four objective measures of project quality—bug severity, component complexity, coordinative 
complexity, and dynamic complexity. Results largely support our hypotheses, highlighting the interplay between 
project control, agile methodology use, and requirements change. The findings contribute to extant literature by 
integrating control theory into the growing literature on agile methodology use and by identifying specific 
contingencies affecting the efficacy of different control modes. We discuss the theoretical and practical 
implications of our results.
"""

# %%
abs_2 = """
Simultaneously achieving efficiency and flexibility in enterprise software production has been a considerable 
challenge for firms. Newer software development paradigms such as component-based and model-driven development 
attempt to overcome this challenge by emphasizing modular design of complex systems. However, there is a paucity of 
rigorous empirical research on the use of such software methodologies and the associated extent to which trade-offs 
between efficiency and flexibility can be influenced. Addressing this gap, we investigate the performance outcomes of 
a model-driven, component-based software development methodology using data collected from an enterprise software 
development firm that deployed such a methodology for its product development processes. Examining the design, 
development, and implementation of 92 business software components of the firm's enterprise resource planning product,
we discuss how the design of software components, specifically component granularity, affects development efficiency 
(development effort and defects) and flexibility (customization effort). Our results suggest that (a) components that 
are coarse grained are associated with higher flexibility (lower customization effort) but are also associated with 
lower development efficiency (more development effort and defects), and (b) defect proneness of a component plays a 
mediating role on the relationship between component granularity and flexibility. These findings present strong 
evidence for the existence of trade-offs between efficiency and flexibility in mass-customized software product life 
cycles. They establish component granularity as a key design dimension that needs to be managed judiciously to enable
potential trade-off shifting mechanisms through the use of software methodologies that emphasize modular design 
approaches.
"""

# %%
cb_v = """
Humans possess the remarkable ability to perceive color, shape, and motion, and to differentiate between light
intensities varied by over nine orders of magnitude. Phototransduction—the process in which absorbed photons are 
converted into electrical responses—is the first stage of visual processing, and occurs in the outer segment, the 
light-sensing organelle of the photoreceptor cell. Studies of genes linked to human inherited blindness have been 
crucial to understanding the biogenesis of the outer segment and membrane-trafficking of photoreceptors.
"""

# %%
cb_t = """
Taste buds are aggregates of 50–100 polarized neuroepithelial cells that detect nutrients and other compounds. 
Combined analyses of gene expression and cellular function reveal an elegant cellular organization within the taste 
bud. This review discusses the functional classes of taste cells, their cell biology, and current thinking on how 
taste information is transmitted to the brain.
"""

# %%
abs_3 = """
This article will discuss the various windowing systems which are currently (or will be shortly) available. The 
difficulties of developing under these new environments will lead into a discussion of object-oriented programming 
techniques and how they can be used to facilitate the development of complex windows-based programs.
"""

# %%
abs_4 = """
Software contracting is a multi-faceted issue that involves legal, economic, managerial and technological 
considerations. To better understand the economic aspect of software contracting, this paper provides a summary review
of software development contracts, followed by a game-theoretic model developed to incorporate incentive and 
information issues associated with software contracting. In the model an outside contractor is hired to develop a 
software system over multiple periods. Due to the uncertainties about costs or technology, the developer faces the 
risk of having to abandon the project at an intermediate phase. The user is better informed of the benefit of the 
system, while the developer privately discovers the development costs as the project advances. Given the limited 
information, the contracting parties make decisions in their own interest, leaving each party vulnerable to the 
other's opportunistic behavior. In this setting, we construct a viable contract that aligns the incentives of the 
contracting parties and produces the same equilibrium outcome as in in-house development. We also relate the 
implications of the model to the actual contract cases.
"""

# %%
cb_v_vector = tfidf_vectorizer.transform([cb_v])

# %%
cb_t_vector = tfidf_vectorizer.transform([cb_t])

# %%
# kmeans_250.labels_
# Out:
# array([ 85, 230,  27, ...,  31,  36, 246], dtype=int32)

# %%
# model_250.predict(cb_v_vector)
# Out:
# array([14], dtype=int32)

# %%
# model_250.predict(cb_t_vector)
# Out:
# array([14], dtype=int32)

# %%
# model_250.predict(tfidf_vectorizer.transform([abs_1, abs_2, cb_v, cb_t]))
# Out:
# array([14, 14, 14, 14], dtype=int32)

# %% [markdown]
# All 4 of those abstracts probably should not be the same category. Try more clusters.

# %% [markdown]
# ### n_clusters = 1000

# %%
kmeans_1000 = MiniBatchKMeans(n_clusters=1000, batch_size=1500)

# %%
model_1000 = kmeans_1000.fit(tfidf)

# %%
model_1000.predict(tfidf_vectorizer.transform([abs_1, abs_2, cb_v, cb_t]))
# Out:
# array([697, 697, 916, 221], dtype=int32)

# %%
model_1000.predict(tfidf_vectorizer.transform([]))
# Out:
# array([794], dtype=int32)

# %%
model_1000.predict(tfidf_vectorizer.transform([]))
# Out:
# array([697], dtype=int32)

# %% [markdown]
# ### n_clusters = 750 (currently in use)

# %%
kmeans_750 = MiniBatchKMeans(n_clusters=750, batch_size=1000)

# %%
model_750 = kmeans_750.fit(tfidf_wt)

# %%
model_750.predict(tfidf_vectorizer.transform([abs_1, abs_2, cb_t, cb_v, abs_3, abs_4]))
# Out:
# array([547, 163, 163,  72, 622, 163], dtype=int32)

# %%
model_750.labels_
# Out:
# array([720,  97,  41, ..., 311, 397, 433], dtype=int32)

# %%
model_750.predict(tfidf_vectorizer.transform([3 * papers.iloc[0]['title'] + papers.iloc[0]['abstract']]))
# Out:
# array([720], dtype=int32)

# %%
papers.iloc[0]['title']
# Out:
# 'Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies'

# %%
print(papers.iloc[0]['abstract'])
# Out:
#   A fully differential calculation in perturbative quantum chromodynamics is
# presented for the production of massive photon pairs at hadron colliders. All
# next-to-leading order perturbative contributions from quark-antiquark,
# gluon-(anti)quark, and gluon-gluon subprocesses are included, as well as
# all-orders resummation of initial-state gluon radiation valid at
# next-to-next-to-leading logarithmic accuracy. The region of phase space is
# specified in which the calculation is most reliable. Good agreement is
# demonstrated with data from the Fermilab Tevatron, and predictions are made for
# more detailed tests with CDF and DO data. Predictions are shown for
# distributions of diphoton pairs produced at the energy of the Large Hadron
# Collider (LHC). Distributions of the diphoton pairs from the decay of a Higgs
# boson are contrasted with those produced from QCD processes at the LHC, showing
# that enhanced sensitivity to the signal can be obtained with judicious
# selection of events.

# %%
cluster_720 = np.where(model_750.labels_ == 720)[0]

# %%
papers.iloc[cluster_720]
# Out:
#                                                         title  \
# id
# 0704.0001   Calculation of prompt diphoton production cros...
# 0704.0031   Crystal channeling of LHC forward protons with...
# 0704.0235   The Determination of the Helicity of $W'$ Boso...
# 0704.0254        Unravelling the sbottom spin at the CERN LHC
# 0704.0294   QED x QCD Resummation and Shower/ME Matching f...
# ...                                                       ...
# 1905.10106         LHC Constraints on a $(B-L)_3$ Gauge Boson
# 1905.10419  Rescattering effects in antiproton-induced exc...
# 1905.12953  Non-Resonant Searches for Axion-Like Particles...
# 1906.00894  Near threshold $J/\psi$ and $\Upsilon$ photo-p...
# 1906.01063  Constraining R-parity-violating couplings in $...
#
#                                                       authors  \
# id
# 0704.0001   [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 0704.0031              [[Biryukov, V. M., , Serpukhov, IHEP]]
# 0704.0235                              [[Rizzo, Thomas G., ]]
# 0704.0254            [[Alves, Alexandre, ], [Eboli, Oscar, ]]
# 0704.0294               [[Ward, B. F. L., ], [Yost, S. A., ]]
# ...                                                       ...
# 1905.10106             [[Elahi, Fatemeh, ], [Martin, Adam, ]]
# 1905.10419  [[Larionov, A. B., ], [Gillitzer, A., ], [Stri...
# 1905.12953  [[Gavela, M. B., ], [No, J. M., ], [Sanz, V., ...
# 1906.00894  [[Hatta, Yoshitaka, ], [Rajan, Abha, ], [Yang,...
# 1906.01063  [[Bansal, Saurabh, ], [Delgado, Antonio, ], [K...
#
#                      submitter  \
# id
# 0704.0001       Pavel Nadolsky
# 0704.0031   Valery M. Biryukov
# 0704.0235      Thomas G. Rizzo
# 0704.0254      Alexandre Alves
# 0704.0294        Scott A. Yost
# ...                        ...
# 1905.10106       Fatemeh Elahi
# 1905.10419     Alexei Larionov
# 1905.12953       Veronica Sanz
# 1906.00894     Yoshitaka Hatta
# 1906.01063      Saurabh Bansal
#
#                                                      abstract  \
# id
# 0704.0001     A fully differential calculation in perturba...
# 0704.0031     We show that crystal can trap a broad (x, x'...
# 0704.0235     Apart from its mass and width, the most impo...
# 0704.0254     Establishing that a signal of new physics is...
# 0704.0294     We present the theory of QED x QCD resummati...
# ...                                                       ...
# 1905.10106    In this paper, we explore the constraints th...
# 1905.10419    On the basis of the generalized eikonal appr...
# 1905.12953    We propose a new collider probe for axion-li...
# 1906.00894    We update our previous calculation of $J/\ps...
# 1906.01063    We find new limits on the $\lambda'_{3jk}$ R...
#
#                                  categories  \
# id
# 0704.0001                          [hep-ph]
# 0704.0031                          [hep-ph]
# 0704.0235                   [hep-ph hep-ex]
# 0704.0254                          [hep-ph]
# 0704.0294                          [hep-ph]
# ...                                     ...
# 1905.10106                         [hep-ph]
# 1905.10419  [nucl-th hep-ex hep-ph nucl-ex]
# 1905.12953                  [hep-ph hep-ex]
# 1906.00894                         [hep-ph]
# 1906.01063                         [hep-ph]
#
#                                     journal-ref  \
# id
# 0704.0001              Phys.Rev.D76:013009,2007
# 0704.0031              Phys.Lett.B658:7-12,2007
# 0704.0235                    JHEP 0705:037,2007
# 0704.0254              Phys.Rev.D75:115013,2007
# 0704.0294     ActaPhys.Polon.B38:2395-2403,2007
# ...                                         ...
# 1905.10106      Phys. Rev. D 100, 035016 (2019)
# 1905.10419                                 None
# 1905.12953  Phys. Rev. Lett. 124, 051802 (2020)
# 1906.00894      Phys. Rev. D 100, 014032 (2019)
# 1906.01063      Phys. Rev. D 100, 093005 (2019)
#
#                                                      comments  \
# id
# 0704.0001             37 pages, 15 figures; published version
# 0704.0031                                 11 pages, 3 figures
# 0704.0235   29 pages, 11 figures; discussion and reference...
# 0704.0254                                 9 pages, 11 figures
# 0704.0294      12 pages, LaTex with packages amsmath, amssymb
# ...                                                       ...
# 1905.10106                               28 pages, 12 figures
# 1905.10419  28 pages, 8 figures, modified sec. 1 and 2, ne...
# 1905.12953  10 pages, 7 figures. New version includes inte...
# 1906.00894                                10 pages, 9 figures
# 1906.01063                       9 pages, 3 figures, 3 tables
#
#                           processed_categories  \
# id
# 0704.0001                             {hep-ph}
# 0704.0031                             {hep-ph}
# 0704.0235                     {hep-ph, hep-ex}
# 0704.0254                             {hep-ph}
# 0704.0294                             {hep-ph}
# ...                                        ...
# 1905.10106                            {hep-ph}
# 1905.10419  {nucl-ex, hep-ph, hep-ex, nucl-th}
# 1905.12953                    {hep-ph, hep-ex}
# 1906.00894                            {hep-ph}
# 1906.01063                            {hep-ph}
#
#                           general_categories
# id
# 0704.0001                             hep-ph
# 0704.0031                             hep-ph
# 0704.0235                     hep-ex, hep-ph
# 0704.0254                             hep-ph
# 0704.0294                             hep-ph
# ...                                      ...
# 1905.10106                            hep-ph
# 1905.10419  hep-ex, hep-ph, nucl-ex, nucl-th
# 1905.12953                    hep-ex, hep-ph
# 1906.00894                            hep-ph
# 1906.01063                            hep-ph
#
# [5951 rows x 9 columns]

# %% [markdown]
# ### Save whichever model is most suitable

# %%
with open('model/kmeans.pkl', 'wb') as f:
    pickle.dump(model_1000, f)

# %%
with open('model/tfidf.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# %%
with open('model/tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf_vectorizer, f)

# %% [markdown]
# ## Try using model from loaded .pkl file

# %%
with open('model/kmeans.pkl', 'rb') as f:
    km = pickle.load(f)

# %%
km
# Out:
# MiniBatchKMeans(batch_size=1500, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=1000, n_init=3, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
with open('model/tfidf_vectorizer.pkl', 'rb') as f:
    tfidf_vec = pickle.load(f)

# %%
tfidf_vec
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
km.predict(tfidf_vec.transform(["""
This article puts Marxist and queer theories in conversation with one another to advance thinking about gender and 
sexuality. I argue that Marxist concepts such as class, mode of production, and struggle need to be "borrowed" to 
sharpen queer theory. My arguments are situated in the context of the Philippine literature that has examined the 
local queer experience. Such approach productively re-imagines contemporary discourses and performances of sexuality 
in Philippine society.
"""]))
# Out:
# array([916], dtype=int32)

# %%
km.predict(tfidf_vec.transform([abs_1, abs_2, cb_t, cb_v]))
# Out:
# array([697, 697, 221, 916], dtype=int32)

# %%
km.predict(tfidf_vec.transform(["""
A galvanic or voltaic cell uses a redox reaction to produce an electric current. It consists of two half cells, with 
each half cell containing an electrode (a metal) in a solution of its own ions (Owen, Ahmed, 2015). One type of 
galvanic cell that is frequently used in labs to gather information and analyze data in electrochemistry is the 
Daniell cell (Lauren, 1965). The Daniell cell consists of a zinc electrode in a solution of zinc sulfate, or 
ZnSO4(aq) (which contains Zn2+ ions) and a copper electrode in a solution of copper (II) sulfate, or CuSO4(aq) 
(which contains Cu2+ ions). The two electrodes are connected via a wire, and the solutions are connected via a salt 
bridge containing a solution of sodium sulfate, or Na2SO4(aq), to allow the flow of ions to complete the circuit 
(Queen’s University, 2014). This would cause the following chemical reactions (1) and (2), resulting in the net ionic 
equation (3)
"""]))
# Out:
# array([221], dtype=int32)

# %%
km.predict(tfidf_vec.transform(["""
For guest editor George Henson, it's been a long journey from reading The Front Runner in 1977 in Sapulpa, Oklahoma, to writing about queer lit for World Literature Today. But just as he has found his place here, the writers featured in this issue have taken their place alongside a long list of notable world authors.
"""]))
# Out:
# array([916], dtype=int32)
