# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# CORD-19 intertias

# %%
x1 = range(800, 1600, 100)

# %%
y1 = [31369.769556741187, 30823.046874681786, 30156.365116434987, 29825.51869647369, 29548.5263670659, 29280.177303535726, 29210.762259497402, 28965.333986817248]

# %%
plt.plot(x1, y1, '-o')

# %% [markdown]
# arXiv intertias

# %%
x2 = range(500 , 1500, 100)

# %%
y2 = [1070654.7983313387, 1055878.8580052515, 1071050.3050894067, 1080557.9223193543, 1054206.6260130312, 1038805.2381671381, 1027861.6906680305, 1019867.3937377292, 1014654.2580211975, 1009231.0438412542]

# %%
plt.plot(x2, y2, '-o')
